# %%
import pandas as pd

splits = {'train': 'data/train-00000-of-00001-9df3a936e1f63191.parquet', 'test': 'data/test-00000-of-00001-af2a9f454ad1b8a3.parquet'}
df = pd.read_parquet("hf://datasets/neural-bridge/rag-dataset-12000/" + splits["train"])

# %%
df
# Out:
#                                                 context  \
# 0     Caption: Tasmanian berry grower Nic Hansen sho...
# 1     RWSN Collaborations\nSouthern Africa Self-supp...
# 2     All Android applications categories\nDescripti...
# 3     How unequal is India? The question is simple, ...
# 4     Gunnar Nelson took his time on the feet agains...
# ...                                                 ...
# 9595  For teenagers, getting their first car is a ri...
# 9596  I Sold the Farm (farm #1) for a client in cent...
# 9597  Entry 150, during the Classic how many boats w...
# 9598  Ok, they aren't real interrupts... its actuall...
# 9599  Moonview Highway is a race track appearing in ...
#
#                                                question  \
# 0     What is the Berry Export Summary 2028 and what...
# 1     What are some of the benefits reported from ha...
# 2     What are the unique features of the Coolands f...
# 3     What is the main difference between the Nation...
# 4     How did Gunnar Nelson win the fight against Za...
# ...                                                 ...
# 9595  What are some ways to lower the cost of a teen...
# 9596  What was the unique action taken by the buyer ...
# 9597  How does VanDam cope with the pressures and di...
# 9598    What does the program written by the author do?
# 9599  What happens when a player with a Mega Mushroo...
#
#                                                  answer
# 0     The Berry Export Summary 2028 is a dedicated e...
# 1     Benefits reported from having access to Self-s...
# 2     The unique features of the Coolands for Twitte...
# 3     The main difference between the NSS and the IH...
# 4     Gunnar Nelson won the fight against Zak Cummin...
# ...                                                 ...
# 9595  Some ways to lower the cost of a teenager's ca...
# 9596  The buyer took the brand new sign of the selle...
# 9597  VanDam copes with the pressures and distractio...
# 9598  The program written by the author locks the sh...
# 9599  Players who have the Mega Mushroom in effect m...
#
# [9600 rows x 3 columns]

# %%
pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\timur\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\timur\anaconda3\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\timur\anaconda3\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\timur\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\timur\anaconda3\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\timur\anaconda3\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\timur\anaconda3\lib\site-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in c:\users\timur\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.24.0 in c:\users\timur\anaconda3\lib\site-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in c:\users\timur\anaconda3\lib\site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\timur\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\timur\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\timur\anaconda3\lib\site-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\timur\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\timur\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\timur\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\timur\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\timur\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\timur\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\timur\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\timur\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\timur\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\timur\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\timur\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\timur\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\timur\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\timur\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\timur\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl (30 kB)
# Installing collected packages: xxhash, multiprocess, datasets
# Successfully installed datasets-3.6.0 multiprocess-0.70.16 xxhash-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
prompt = """
You are a knowledgeable and helpful chatbot designed to answer questions based on a specific text provided by the user. Your goal is to deliver accurate and concise answers by closely analyzing the content of the given text. 
Follow these guidelines to ensure high-quality responses:
1. Careful Analysis:
   - Thoroughly read and understand the given text before attempting to answer any questions.
   - Identify key details, themes, and important points within the text.

2. Relevant Responses:
   - Provide answers that are directly relevant to the information contained in the text.
   - Avoid using external knowledge or assumptions not supported by the text unless explicitly instructed to do so.

3. Clarity and Precision:
   - Ensure answers are clear, precise, and to the point.
   - Use simple and direct language for better understanding.

4. Text Quotation:
   - When beneficial, quote directly from the text to support your answers. Ensure quoted material is relevant and clearly attributed.

5. If Uncertain:
   - If the text does not provide enough information to answer a question, politely inform the user that the answer cannot be determined from the text.

6. Respectful Communication:
   - Always communicate respectfully and politely, maintaining a helpful tone.
"""

# %%
dfstart=df.copy()

# %%
df=df[:1000]

# %%
# from tqdm.notebook import tqdm


# answers = []
# for message in tqdm(df.context.values):
#     messages = [
#     ("system",prompt),
#     ("human",message)
#            ]
#     answer = llm.invoke(messages).content
#     answers.append(answer)#eval(answer[answer.find("{"):])['classification'])

# %%
df
# Out:
#                                                context  \
# 0    Caption: Tasmanian berry grower Nic Hansen sho...
# 1    RWSN Collaborations\nSouthern Africa Self-supp...
# 2    All Android applications categories\nDescripti...
# 3    How unequal is India? The question is simple, ...
# 4    Gunnar Nelson took his time on the feet agains...
# ..                                                 ...
# 995  Last Sunday, as part of a brunch with friends,...
# 996  Printable View\nhow often does Orlando Hire?\n...
# 997  A recent survey of Canadian workers by pension...
# 998  As soon as it hits October I start planning my...
# 999  At some point a couple of weeks ago my blog tu...
#
#                                               question  \
# 0    What is the Berry Export Summary 2028 and what...
# 1    What are some of the benefits reported from ha...
# 2    What are the unique features of the Coolands f...
# 3    What is the main difference between the Nation...
# 4    How did Gunnar Nelson win the fight against Za...
# ..                                                 ...
# 995  What was the unanimous favourite chocolate bar...
# 996  What does the SAFER grant require Orlando to d...
# 997  What percentage of Canadian workers with a tra...
# 998  What type of pears are recommended for making ...
# 999  Why did the author decide to leave Blogger for...
#
#                                                 answer
# 0    The Berry Export Summary 2028 is a dedicated e...
# 1    Benefits reported from having access to Self-s...
# 2    The unique features of the Coolands for Twitte...
# 3    The main difference between the NSS and the IH...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  The unanimous favourite was the Organic Cappuc...
# 996  The SAFER grant requires Orlando to replace an...
# 997  50 per cent of workers with a traditional defi...
# 998  Anjou pears, Bosc pears, and Bartlett pears ar...
# 999  The author decided to leave Blogger because it...
#
# [1000 rows x 3 columns]

# %%
from langchain_ollama.chat_models import ChatOllama
import pandas as pd
llm = ChatOllama(
    model="llama3.1",
    #temperature=0.7,  
    #request_timeout=30 
    #"Gemma3:12b"
)

# %%
from tqdm.notebook import tqdm

results = []  

for _, row in tqdm(df.iterrows(), total=df.shape[0]):
    system_message = (
        f"{prompt}\n"
        f"Context: {row['context']}\n"
    )
    messages = [
        ("system", system_message),
        ("human", row["question"])
    ]
    try:
        answer = llm.invoke(messages).content
        results.append(answer)
    except: results.append('popa')
df['answerllama8b']=results
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# C:\Users\timur\AppData\Local\Temp\ipykernel_9564\540472230.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['answerllama8b']=results

# %%
df['answerllama8b']=results
# Out:
# C:\Users\timur\AppData\Local\Temp\ipykernel_9564\2433511695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['answerllama8b']=results

# %%
from langchain_ollama.chat_models import ChatOllama
import pandas as pd
llm = ChatOllama(
    model="llama3.2:3b",
    #temperature=0.7,  
    #request_timeout=30 
    #"Gemma3:12b"
)
results = []  

for _, row in tqdm(df.iterrows(), total=df.shape[0]):
    system_message = (
        f"{prompt}\n"
        f"Context: {row['context']}\n"
    )
    messages = [
        ("system", system_message),
        ("human", row["question"])
    ]
    try:
        answer = llm.invoke(messages).content
        results.append(answer)
    except: results.append('popa')
df['answerllama3b']=results
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# C:\Users\timur\AppData\Local\Temp\ipykernel_9564\3580261047.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['answerllama3b']=results

# %%
from langchain_ollama.chat_models import ChatOllama
import pandas as pd
llm = ChatOllama(
    model="Gemma3:12b",
    #temperature=0.7,  
    #request_timeout=30 
    #"Gemma3:12b"
)
results = []  

for _, row in tqdm(df.iterrows(), total=df.shape[0]):
    system_message = (
        f"{prompt}\n"
        f"Context: {row['context']}\n"
    )
    messages = [
        ("system", system_message),
        ("human", row["question"])
    ]
    try:
        answer = llm.invoke(messages).content
        results.append(answer)
    except: results.append('popa')
df['answerGemma3:12b']=results
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# C:\Users\timur\AppData\Local\Temp\ipykernel_9564\1570010814.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['answerGemma3:12b']=results

# %%
df2=df.copy()

# %%
df=df2[:1000]

# %%
import re
import json
import pandas as pd
from typing import Dict
from langchain_ollama.chat_models import ChatOllama
from langchain_core.messages import HumanMessage, SystemMessage

def sanitize_json_string(response_str: str) -> str:
    response_str = response_str.strip()
    if response_str.startswith("```"):
        response_str = re.sub(r"^```(?:\s*json\s*)?\n", "", response_str)
        response_str = re.sub(r"\n```$", "", response_str)
    return response_str
llm2 = ChatOllama(
    model="phi4",  
    temperature=0.0, 
)

def evaluate_answers(context: str, question: str, reference_answer: str, llama_answer: str) -> Dict[str, int]:
    prompt = f"""
You are an expert in evaluating the quality of AI-generated answers. Rate the model's response on a scale from 1 to 10 (1 = Poor, 10 = Excellent). Your evaluation must be extremely strict. Award a score of 10 only when the answer is flawless in every aspect.

Context: {context}
Question: {question}
Reference Answer: {reference_answer}
Model's Answer: {llama_answer}

### Evaluation Criteria
1. Answer Correctness – How precisely the model’s answer matches the reference answer.
2. Faithfulness – Whether the answer aligns accurately with the provided context.
3. Answer Relevance – How directly the answer responds to the question.

Make sure that:
• A score of 10 is only reserved for answers that are completely ideal and without any error.
• Scores below 10 reflect the presence of even minor imperfections or deviations.

Return ONLY a JSON object without any explanation, using one of the following formats:
{{
  "answer_correctness": 8,
  "faithfulness": 6,
  "answer_relevance": 10
}}

"""
    messages = [
        SystemMessage(content="You are an AI evaluation expert. Provide ONLY JSON output"),
        HumanMessage(content=prompt)
    ]
    
    response = llm2.invoke(messages)
    response_str = sanitize_json_string(response.content)
    
    try:
        return json.loads(response_str)
    except json.JSONDecodeError:
        print(f"Parsing error: {response.content}")
        return {
            "answer_correctness": -1,
            "faithfulness": -1,
            "answer_relevance": -1
        }
results = []
for _, row in df.iterrows():
    eval_result = evaluate_answers(
        context=row["context"],
        question=row["question"],
        reference_answer=row["answer"],
        llama_answer=row["answerllama3b"]
    )
    results.append(eval_result)
df_eval = pd.DataFrame(results)
df_final = pd.concat([df, df_eval], axis=1)
df_final.rename(columns={'answer_correctness': 'answer_correctness_llama3b'}, inplace=True)
df_final.rename(columns={'faithfulness': 'faithfulness_llama3b'}, inplace=True)
df_final.rename(columns={'answer_relevance': 'answer_relevance_llama3b'}, inplace=True)
print(df_final)
# Out:
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 8
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer captures the metaphorical use of 'quantum' in relation to time and writing, but it does not explicitly mention all definitions provided in the reference answer. It focuses more on the author's personal reflection rather than providing a comprehensive definition.
#
# - **Faithfulness (9):** The model accurately reflects the context by discussing how 'quantum' is used metaphorically in the text to describe small amounts of time or courage, aligning well with the author's perspective.
#
# - **Answer Relevance (8):** The answer addresses the question about the meaning of 'quantum' in context but could have been more direct in linking back to all aspects of the reference definition. It is relevant but slightly indirect in addressing the full scope of the word's meanings as per the reference.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (7):** The model's answer includes the correct benefits mentioned in the reference answer but adds an additional point about building a strong portfolio and experience, which is not part of the reference answer. This introduces minor inaccuracies.
#
# - **Faithfulness (9):** The model accurately reflects most of the context provided, correctly identifying the main benefits of joining the SPJ Austin Student Chapter as stated in the text.
#
# - **Answer Relevance (10):** The response directly addresses the question about the benefits of joining the SPJ Austin Student Chapter and is relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation for Scores:**
#
# - **Answer Correctness (9):** The model's answer closely matches the reference answer by identifying key purposes of the program. It correctly mentions setting a standard, encouraging exploration and professional growth, distinguishing professionals, and enhancing resumes. However, it slightly rephrases "passionate about professionalism" as recognizing excellence, which is a minor deviation.
#
# - **Faithfulness (9):** The model's response aligns well with the context provided in the text. It accurately reflects the program’s goals and benefits as described. The slight rewording does not misrepresent the content but introduces a subtle difference from the reference answer.
#
# - **Answer Relevance (10):** The model directly addresses the question about the purpose of the Virginia Environmental Education Certification program, making it highly relevant to the query.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 7,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer correctly states that PXI-8512 modules can be used to send and receive data with CAN protocol between two PXI 8880 controllers, aligning well with the reference answer. However, it includes additional information about alternative methods suggested by Nick, which is not part of the reference answer.
#
# - **Faithfulness (7):** The model's response accurately reflects the context provided in the conversation, including both the direct confirmation and the suggestion for an alternative method. However, the inclusion of extra details slightly deviates from a strict interpretation of the reference answer.
#
# - **Answer Relevance (10):** The model's answer directly addresses the question about using PXI-8512 modules with CAN protocol between two controllers, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 5,
#   "faithfulness": 4,
#   "answer_relevance": 7
# }
# ```
#
# Explanation:
# - **Answer Correctness (5):** The model's answer incorrectly identifies the main conflict as Evie's rivalry with another character, which is not mentioned in the reference. The correct conflict involves saving Jack from "The Lovers" and potentially allying with Death.
#
# - **Faithfulness (4):** The model introduces elements like a rivalry that are not present in the provided context or reference answer, leading to inaccuracies.
#
# - **Answer Relevance (7):** While the model does address the theme of survival and interaction between characters, it misidentifies the specific conflict, making it only partially relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all key strategies mentioned. However, it includes additional context about the benefits of each strategy, which is not explicitly required by the question.
# - **Faithfulness (9):** The response accurately reflects the content and intent of the provided text, with no significant deviations or inaccuracies.
# - **Answer Relevance (10):** The model's answer directly addresses the question regarding strategies to improve call center efficiency and effectiveness.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all major steps in the routine of an Early Intervention Specialist/Service Coordinator. It includes receiving referrals, discussing concerns with families, evaluating hearing and communication abilities, scheduling evaluations, and coordinating home visits. A minor deduction is made because it does not explicitly mention providing other resources like potty training suggestions or insurance coverage help.
#
# - **Faithfulness (9):** The model's answer accurately reflects the context provided in the original text. It maintains the sequence of actions and considerations described by the specialist, ensuring that the essence of their routine is preserved. A slight deduction is made for not mentioning additional resources provided to families, which are part of the broader role.
#
# - **Answer Relevance (10):** The model's answer directly addresses the question about the routine of an Early Intervention Specialist/Service Coordinator, focusing on the key activities involved in coordinating services for babies with developmental delays and/or disorders. It is highly relevant and specific to the query posed.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 8,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer includes several key features mentioned in the reference, such as the In Case of Emergency menu and LED light. However, it omits some details like text messaging capabilities and FM radio, which are part of the reference answer.
# - **Faithfulness (8):** The model accurately reflects most aspects of the context provided but misses a few specific features mentioned in the reference answer.
# - **Answer Relevance (9):** The response is relevant to the question about the phone's features, though it lacks completeness by omitting some details.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation:
# - **Answer Correctness (9):** The model's answer closely aligns with the reference, capturing the essence of reconnecting women to their feminine power and emphasizing personal empowerment. However, it slightly expands beyond the specific mention of Mother Earth in the reference.
# - **Faithfulness (9):** The response is faithful to the context provided, accurately reflecting themes from the text about reconnection, intuition, creativity, and balance between masculine and feminine energies.
# - **Answer Relevance (10):** The model's answer directly addresses the question regarding the main theme of the book, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer captures some of the key points from the reference, such as being careful and considering insurance. However, it does not explicitly mention limiting liquor liability, which is a crucial part of the advice.
#
# - **Faithfulness (7):** The model accurately reflects parts of the context but misses out on directly stating that hosts should limit their liquor liability, which was clearly mentioned in the reference answer.
#
# - **Answer Relevance (9):** The response is relevant to the question as it addresses the main points about being careful and considering insurance. However, it lacks completeness by not mentioning all aspects of the advice given in the context.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer incorrectly states that marijuana was recorded as the "most safe" instead of "far safer than alcohol." This is a significant error, but it does correctly mention the comparison between marijuana and alcohol.
#
# - **Faithfulness (5):** The model introduces an incorrect term ("most safe") which deviates from the context. Additionally, it adds unnecessary commentary about contradicting previous assumptions, which was not part of the reference answer.
#
# - **Answer Relevance (9):** The response is mostly relevant to the question as it addresses the key findings regarding marijuana and alcohol, but the inaccuracies slightly detract from its relevance.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (7):** The model's answer includes some functions mentioned in the reference, such as providing a seat and storage space. However, it also introduces additional details not present in the reference answer, like flexibility in design, comfort needs, functionality beyond seating, aesthetic purposes, and multi-functional use in home decor.
#
# - **Faithfulness (7):** The model's response is generally faithful to the context but includes extra information that goes beyond what was specifically asked for. This additional detail slightly deviates from the reference answer.
#
# - **Answer Relevance (9):** The model's answer is largely relevant, addressing the question about functions of barstools counter stools on sale ivory swivel. However, it extends into areas not directly requested by the question, such as design flexibility and aesthetic purposes.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# The model's answer is highly accurate and aligns well with the reference answer, covering all main ingredients mentioned. It maintains faithfulness to the context by accurately reflecting the information provided in the text. The relevance of the response directly addresses the question about the composition of lip gloss. Minor deductions are made for slight variations in wording and structure compared to the reference answer, but overall, it is a comprehensive and precise response.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer by listing the same places and providing additional context from Jonathan Gold's review. However, it includes more detail than strictly necessary for correctness.
# - **Faithfulness (9):** The model accurately reflects the content of the provided context, including specific details about each restaurant that align with the original text.
# - **Answer Relevance (10):** The answer directly addresses the question by listing places where excellent pork belly can be found in Koreatown.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is mostly correct but omits the "Consult with Us" program mentioned in the reference answer. It correctly identifies Cooking Classes, School Gardens, and Events.
# - **Faithfulness (9):** The response aligns well with the context provided, accurately describing each of the programs mentioned except for missing the Consultation aspect.
# - **Answer Relevance (10):** The model's answer directly addresses the question about volunteering opportunities at EATS.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most of the key changes mentioned by Haribabu Kommi. However, it omits some details such as the mention of tuple format assumptions and specific pending comments from Andres.
#
# - **Faithfulness (9):** The model accurately reflects the content of the email, maintaining alignment with the context provided. It includes most of the significant changes but misses a few finer points.
#
# - **Answer Relevance (10):** The response directly addresses the question about changes to the storage AM, making it highly relevant and focused on the query.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer states that the ideal range is 0.61% to 1.50%, which includes a broader range than specified in the reference answer (.5 percent to as much as 1 percent). This introduces an error, though it does correctly identify high carbon steel.
# - **Faithfulness (9):** The model's response aligns well with the context provided, accurately describing high carbon steel and its properties. However, it slightly misrepresents the ideal range for sword making by including a broader spectrum than specified in the reference answer.
# - **Answer Relevance (10):** The model directly addresses the question about the ideal range of carbon content for sword making, providing relevant information from the context.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer paraphrases Mitch Hurwitz's statement but does not directly quote or accurately reflect the specific condition ("You gotta watch them in order"). It introduces a slight misinterpretation by focusing on "setup follows the punchline" rather than the viewing order.
#
# - **Faithfulness (7):** While the model captures the essence of Mitch Hurwitz's tweet, it does not precisely convey his intended message about watching episodes in order. The paraphrasing leads to a minor deviation from the original context.
#
# - **Answer Relevance (9):** The answer is relevant and addresses the question directly by discussing the condition imposed by Mitch Hurwitz, though it slightly misinterprets the specific requirement.
# Parsing error: ```json
# {
#   "answer_correctness": 3,
#   "faithfulness": 4,
#   "answer_relevance": 5
# }
# ```
#
# Explanation of Scores:
# - **Answer Correctness (3):** The model's answer incorrectly identifies Reddington as the character being read about, whereas the correct reference is Dorothy from the Wizard of Oz. This represents a significant deviation from the correct information.
#
# - **Faithfulness (4):** While the context does discuss Reddington and Lady Ambrosia, these are not directly related to what Liz reads to her unborn child. The model's answer introduces elements that are not faithful to the specific passage being read.
#
# - **Answer Relevance (5):** The model's response addresses a different aspect of the narrative rather than focusing on who is being read about by Liz. It partially relates to the episode but does not directly answer the question posed.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# **Explanation of Scores:**
#
# - **Answer Correctness (7):** The model's answer suggests that the New Hampshire paper does not actively oppose gay marriage, which is a deviation from the reference answer stating they are against it. This misinterpretation affects correctness.
#
# - **Faithfulness (5):** While the model captures some elements of the context, such as the editor's statement about marriage being between a man and a woman, it introduces an interpretation that the paper does not actively oppose gay marriage, which is not supported by the reference answer. This misalignment reduces faithfulness.
#
# - **Answer Relevance (9):** The model directly addresses the question regarding the stance of the New Hampshire paper on gay marriage, making the response highly relevant to the query.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most of the sustainability measures. However, it incorrectly states that food waste is composted instead of donated to the Rainbow Group.
# - **Faithfulness (9):** The response aligns well with the provided context but slightly misrepresents the handling of excess food by mentioning composting rather than donation.
# - **Answer Relevance (10):** The answer directly addresses the question about sustainability and waste reduction measures, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing key points such as job safety, long-term implications, reliability, and liability. It also mentions O'Hara Electric's experience, education, and licensing, which are relevant but not explicitly stated in the reference answer.
#
# - **Faithfulness (9):** The model accurately reflects the context provided, including the reasons for hiring a professional electrician and emphasizing O'Hara Electric's qualifications.
#
# - **Answer Relevance (10):** The response directly addresses why it is recommended to hire a professional residential electrician like O’Hara Electric, making it highly relevant to the question.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer captures some key points but omits several important details from the reference answer, such as requirements for PSPs to issue invoices in hard currency and maintain specific bank accounts, restrictions on opening offshore accounts without authorization, and reconciliation obligations.
#
# - **Faithfulness (5):** While the model accurately reflects parts of the context, it misses significant elements like the settlement conditions for goods and services procured by Agents, the requirement for PSPs to open bank accounts in Euro or US$, and the prohibition on opening offshore accounts without authorization.
#
# - **Answer Relevance (9):** The answer is relevant as it addresses the main topic of new terms and conditions but lacks comprehensive coverage of all aspects mentioned in the reference.
# Parsing error: ```json
# {
#   "answer_correctness": 10,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness**: The model's answer correctly identifies "Concrete" as the title of the second part, matching the reference answer perfectly.
# - **Faithfulness**: The additional information provided about the project is accurate and relevant but not necessary to directly answer the question. This slight deviation from a concise response results in a score of 9.
# - **Answer Relevance**: The model's answer directly addresses the question by providing the title "Concrete," making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference answer, capturing the main purpose of the Asheville Arts Alive web portal. It includes additional context from Kitty Love that enriches the explanation without deviating from the core message.
#
# - **Faithfulness (9):** The model accurately reflects the information provided in the context, including quotes and intentions behind the portal's launch. However, it slightly expands beyond the reference answer by incorporating an extra quote.
#
# - **Answer Relevance (10):** The response directly addresses the question about the purpose of the Asheville Arts Alive web portal, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost perfect, listing all ingredients accurately. However, it includes a minor redundancy by specifying "a little coconut oil" twice in different contexts (for the pan and as an ingredient), which could be seen as slightly less precise.
# - **Faithfulness (10):** The model faithfully represents the information from the context without adding or omitting any critical details about the ingredients.
# - **Answer Relevance (10):** The response directly addresses the question by listing all necessary ingredients, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is highly accurate and closely matches the reference answer. It includes all key points from the guidelines, but it slightly rephrases some parts compared to the reference.
# - **Faithfulness (10):** The model's response aligns perfectly with the provided context, accurately reflecting the group's guidelines without any distortion or omission of critical details.
# - **Answer Relevance (10):** The answer directly addresses the question about the Namasté group's interaction guidelines and is entirely relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost entirely correct, capturing most of the insights listed in the reference. However, it omits two points: "Focus on Generation Z" and "Post-Pandemic Conclusions."
# - **Faithfulness (9):** The response accurately reflects the context provided, listing the insights as mentioned in the text.
# - **Answer Relevance (10):** The answer directly addresses the question by listing the top insights from the market research reports.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, including all key points. However, it adds additional information about Syspeace that was not part of the reference answer.
# - **Faithfulness (9):** The model accurately reflects the context provided, but includes extra details about Syspeace which were not explicitly required by the question.
# - **Answer Relevance (10):** The response directly addresses the question and provides relevant measures to prevent computer virus attacks.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most of the key points such as upgrading content on Facebook, running ads, hosting gatherings, and sharing opportunities. However, it slightly deviates by not mentioning the role of social media in breaking down employer myths or cementing relationships with organizations.
# - **Faithfulness (9):** The model's response is faithful to the context provided, accurately reflecting the strategies used by the USAID program as described in the text. It includes most relevant details but omits some specific examples like the role of social media in breaking down employer myths and partnerships with other organizations.
# - **Answer Relevance (10):** The answer directly addresses the question about how the USAID Program increased its visibility and engagement through social media, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 5,
#   "faithfulness": 4,
#   "answer_relevance": 7
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (5):** The model's answer does not correctly identify that the function was called by JavaScript event handlers like `onUnload` or `onBlur`. It vaguely suggests JavaScript involvement without specifying how it relates to the popup box.
#
# - **Faithfulness (4):** The response is somewhat faithful but lacks precision. It mentions potential use of `onUnload` and `onBlur`, which aligns with the context, but fails to directly connect these events to the specific action of generating a popup.
#
# - **Answer Relevance (7):** The answer addresses the question about how the function was called by discussing JavaScript event handlers, making it relevant. However, it does not provide a clear or direct explanation for the popup box generation as described in the context.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (7):** The model correctly identifies the last book read as a biography about the deadliest climbing year on Everest. However, it fails to explicitly state that the next book is "The Help," which was mentioned in the context. Instead, it vaguely refers to starting a new book without naming it.
#
# - **Faithfulness (9):** The model's answer aligns well with the provided context, accurately reflecting the details about the last book read and the author's intention to start a new one soon. However, it misses explicitly mentioning "The Help" as the next book.
#
# - **Answer Relevance (10):** The response directly addresses the question by identifying both the last book read and indicating that the author plans to start a new book, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer incorrectly states there are four main types of launch frameworks, omitting the "Three times a year" framework mentioned in the reference. This is a significant omission.
# - **Faithfulness (5):** While the model captures most of the details accurately, it introduces an incorrect statement about not having a formal launch framework at all, which was not part of the original context.
# - **Answer Relevance (9):** The answer directly addresses the question by listing the types of launch frameworks but misses one type and adds extra information not present in the reference.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer closely aligns with the reference answer by identifying compassion and kindness as central themes. It also mentions inner strength and hope, which are consistent with the context provided. However, it does not explicitly mention "helping others in times of suffering," a specific phrase from the reference answer.
#
# - **Faithfulness (9):** The model's response accurately reflects the content and nuances of the provided text. It captures key themes such as compassion, inner strength, and hope, while also mentioning "Decimar" as an additional theme explored in the novel.
#
# - **Answer Relevance (10):** The answer directly addresses the question about the main theme of the novel, making it highly relevant to the query.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer correctly identifies Rep. Danny Davis, Rep. Keith Ellison, and Rep. Barbara Lee as the three Members of Congress who issued statements calling for an end to the blockade of Gaza. However, it incorrectly states that only two members were initially mentioned before adding Rep. Danny Davis later, which is not supported by the context.
# - **Faithfulness (5):** The model's answer misinterprets the sequence and initial mention of the congress members in the provided text. It suggests a misunderstanding of how the statements were issued according to the context.
# - **Answer Relevance (9):** The model's response directly addresses the question about who were the first three Members of Congress to issue a public statement calling for an end to the blockade of Gaza, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation of Scores:
# - **Answer Correctness (7):** The model's answer correctly identifies the year and key figures associated with the origin of American burlesque. However, it omits important details about the nature of burlesque as a subset of literary parody that inverts form and content, which are crucial for full correctness.
#
# - **Faithfulness (7):** The model's answer is faithful to the context provided by Dr. Lucky but lacks depth regarding the historical and cultural nuances mentioned in the reference answer.
#
# - **Answer Relevance (9):** The model's response directly addresses the question about the historical origin of American burlesque, making it highly relevant. However, it does not fully capture all aspects discussed by Dr. Lucky, which slightly affects its relevance score.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all nine steps accurately. However, there is a slight deviation in wording and emphasis on certain details which prevents it from being a perfect match.
# - **Faithfulness (9):** The model's response aligns well with the context provided, maintaining the integrity of the original process described by the scrapbooker. Minor differences in phrasing do not significantly alter the meaning or sequence.
# - **Answer Relevance (10):** The answer directly addresses the question about the process followed by the scrapbooker, providing a clear and relevant response.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer is almost entirely correct. It accurately describes Calvados as an apple brandy from France and mentions its use in the Apple Sidecar cocktail, aligning well with the reference answer. However, it does not explicitly mention the specific measurements of ingredients used in the recipe, which are part of the complete context.
#
# - **Faithfulness (9):** The model's response is faithful to the provided context. It correctly identifies Calvados as a key ingredient and describes its role in the Apple Sidecar cocktail. However, it omits some details about how Calvados can be enjoyed both straight or mixed into cocktails, which was mentioned in the context.
#
# - **Answer Relevance (10):** The model's answer directly addresses the question regarding what Calvados is and how it is used in the context of the Sidecar cocktail. It provides a clear and relevant explanation that aligns with the query.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, listing all key features mentioned. However, it omits mentioning that Greenaddress creates a password and mnemonic, which is part of the reference.
# - **Faithfulness (10):** The model accurately reflects the context provided in the question, including details about 2FA, Dynamic Fees, HD wallets, MultiSig, and Instant Confirmation checkbox.
# - **Answer Relevance (10):** The response directly addresses the question by listing features that make Greenaddress a fancy wallet.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all major steps mentioned. However, it slightly rephrases and organizes them differently than the reference.
# - **Faithfulness (9):** The model accurately reflects the context provided in the text, maintaining the essence of each step without introducing inaccuracies or omissions.
# - **Answer Relevance (10):** The answer directly addresses the question about steps a writer should follow to get their book published, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer includes additional uses of wood lathes that are not mentioned in the reference answer, such as chasing threads and making carbide tools. While these are valid uses, they deviate from the specific tasks listed in the reference.
#
# - **Faithfulness (5):** The model introduces information beyond what is directly stated or implied by the context provided for the question about wood lathes' primary functions. This includes details like creating custom turning/ threading lathe tool bits and making carbide tools, which are not explicitly linked to the core uses of a wood lathe in the reference.
#
# - **Answer Relevance (9):** The model's answer is largely relevant as it addresses various applications of wood lathes, including those mentioned in the context. However, it includes additional details that were not required by the question, slightly reducing its relevance score.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation for Scores:**
#
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most components accurately. However, it slightly deviates by not explicitly mentioning the additional reading list and bibliography as separate items.
#
# - **Faithfulness (9):** The response is faithful to the context provided, correctly identifying and listing the components of the British Medieval Student Guide. It includes all major elements mentioned in the reference answer but omits a few details like the "additional reading list" and "bibliography."
#
# - **Answer Relevance (10):** The model's answer directly addresses the question about the components of the guide, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference answer, capturing all essential details about eligibility and benefits. However, it slightly rephrases some parts of the text without altering meaning.
# - **Faithfulness (10):** The information provided by the model aligns perfectly with the context given in the passage.
# - **Answer Relevance (10):** The response directly addresses the question regarding eligibility and benefits of the Berea City School District Gold Card.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost correct but includes an unnecessary detail ("silk") that was not specified in the reference answer. However, it correctly identifies the white tie as the chosen one.
# - **Faithfulness (9):** The model accurately reflects the context by mentioning the wife's reaction to the white tie, which aligns with the narrative provided.
# - **Answer Relevance (10):** The model directly addresses the question about the type of tie chosen for the wedding.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (7):** The model's answer captures many of the exercises and activities mentioned in the reference, but it omits some specific examples like saying "MMMMM" while rubbing the tummy, making car noises with a pea harvester, mimicking clock sounds, and others. This results in an incomplete representation.
#
# - **Faithfulness (7):** The model's answer is generally faithful to the context provided, accurately reflecting many of the exercises and activities described. However, it misses some details from the original text, affecting its completeness.
#
# - **Answer Relevance (9):** The response directly addresses the question about exercises and activities for facilitating speech in children with cleft palate. It includes relevant examples but lacks full coverage of all mentioned activities.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 8
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (7):** The model's answer correctly identifies b-roll clips and photos but omits reports and fact sheets, which are part of the reference answer. This omission results in a score less than perfect.
#
# - **Faithfulness (9):** The model accurately reflects the content provided in the context regarding available media types like b-roll clips and photos. However, it misses some details such as reports and fact sheets.
#
# - **Answer Relevance (8):** The answer is relevant to the question about the type of media available but lacks completeness by not mentioning all categories listed in the reference answer.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all key features mentioned. It includes additional context about embedding videos and linking to other content, which is relevant but not explicitly listed in the reference.
# - **Faithfulness (9):** The model accurately reflects the information provided in the context, with no significant deviations or inaccuracies.
# - **Answer Relevance (10):** The response directly addresses the question by listing features of Spark Page used for creating a website.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer is largely correct, capturing the essence of the BBC's "most ambitious global wildlife series ever" as Planet Earth Live. It accurately mentions the simultaneous broadcast in 140 countries and the schedule starting on May 6th with repeats every Thursday and Sunday for three weeks. However, it omits specific details about the US and Canada not receiving the live simulcast, which is a minor omission.
#
# - **Faithfulness (9):** The model's answer aligns well with the provided context, accurately reflecting the key points about the series' broadcast strategy and content. It includes information on real-time filming techniques and the involvement of award-winning filmmakers and wildlife specialists. The slight deduction comes from not mentioning the lack of live simulcast in the US and Canada.
#
# - **Answer Relevance (10):** The model's answer directly addresses the question, providing relevant details about the series name, broadcast strategy, and content focus. It is concise and to the point, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is mostly correct and aligns well with the reference answer. It includes all major health coverage options mentioned in the context, such as Aetna Health Insurance, Allstate Workplace benefits, and voluntary benefits through Harvard Pilgrim. However, it omits specific details like American Heritage Dental Insurance and VSP Vision Insurance.
# - **Faithfulness (9):** The model's answer is faithful to the provided context, accurately reflecting the health coverage options described. It maintains the integrity of the information given in the context but misses a couple of specific benefits mentioned.
# - **Answer Relevance (10):** The response directly addresses the question about health coverage options and provides relevant details from the context.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 8
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer includes an additional house with six bedrooms that was not asked for in the question, which introduces unnecessary information. However, it correctly identifies the price and location of the first house.
# - **Faithfulness (9):** The model accurately reflects the context by mentioning both houses listed as 6-bedroom properties but fails to note that only one is relevant to the specific query about a single property.
# - **Answer Relevance (8):** While the answer addresses the question, it includes extraneous information about another house not requested in the question.
# Parsing error: ```json
# {
#   "answer_correctness": 5,
#   "faithfulness": 4,
#   "answer_relevance": 7
# }
# ```
#
# Explanation:
# - **Answer Correctness (5):** The model's answer does not precisely match the reference answer. It provides general benefits of SuitePOS but fails to mention the specific gains for Murray's Cheese and Rally House as stated in the reference.
#
# - **Faithfulness (4):** The model's response deviates from the provided context by making educated guesses rather than sticking strictly to the information given about Murray's Cheese and Rally House.
#
# - **Answer Relevance (7):** While the answer is somewhat relevant, discussing potential benefits of SuitePOS, it does not directly address the specific question regarding Murray's Cheese and Rally House.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is very close to the reference, listing all components accurately. However, it includes additional details about poses and features that are not explicitly part of the outfit itself but rather related accessories or options.
# - **Faithfulness (9):** The response aligns well with the context provided, capturing most elements correctly while adding some extra information about poses and hierarchical feet pose which is relevant but slightly beyond just listing components.
# - **Answer Relevance (10):** The model's answer directly addresses the question by listing the components of the outfit, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, covering most of the key points. However, it omits mentioning snacks and special pockets explicitly.
# - **Faithfulness (9):** The response is faithful to the context provided, accurately reflecting the considerations mentioned in the original text with minor omissions.
# - **Answer Relevance (10):** The model's answer directly addresses the question about considerations for driving during pregnancy.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer by listing difficulty sleeping, pain or discomfort, and changes in medical condition as reasons to consider buying a new bed. However, it omits mentioning that these issues should be treated as early warning signs of more serious problems.
#
# - **Faithfulness (9):** The model accurately reflects the context provided, capturing the main points about sleep difficulties and medical conditions affecting sleep quality. It also correctly notes the importance of good sleep.
#
# - **Answer Relevance (10):** The answer directly addresses the question by listing reasons to consider buying a new bed, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is largely correct, capturing the essence of setting measurable goals throughout January and acknowledging that things may not go as planned. However, it slightly misses mentioning the practice of picking a meaningful scripture annually and monthly.
#
# - **Faithfulness (9):** The response aligns well with the context provided in the text, accurately reflecting the author's approach to goal-setting and their understanding of life’s unpredictability.
#
# - **Answer Relevance (10):** The model's answer directly addresses the question about the author's practice for setting goals and resolutions, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer includes some roles and accomplishments not mentioned in the reference, such as Redleaf Polhill PR, which is unrelated to music and culture. It also omits the Trustee of the Susan Chilcott Scholarship Fund.
# - **Faithfulness (7):** While most information aligns with the context, the inclusion of Redleaf Polhill PR deviates from the focus on music and culture.
# - **Answer Relevance (9):** The answer is mostly relevant to the question about Ian's roles in music and culture but includes some unrelated details.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing the essence of what arrangements a Part D sponsor might need to make. However, it slightly lacks the explicit mention of providing "clear guidance regarding how to proceed after a temporary fill is provided," which was part of the context.
# - **Faithfulness (9):** The model's response aligns well with the provided context and accurately reflects the necessary actions for a Part D sponsor at the end of the transition period. It does not introduce any incorrect information or misinterpretations.
# - **Answer Relevance (10):** The answer directly addresses the question about arrangements needed by a Part D sponsor, making it highly relevant to the query posed.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, covering all main points: becoming friends with their friends, monitoring social media habits, and using reverse phone lookup. A minor deduction is made because it adds a cautionary note not present in the reference.
#
# - **Faithfulness (9):** The model accurately reflects the context provided, including specific methods mentioned like PeopleFinders' reverse phone lookup. It maintains the essence of the original text but includes additional advice on handling the situation.
#
# ...
#
# - **Answer Relevance (9):** The model's answer is highly relevant to the question, focusing on the scenic and cultural aspects that make the route significant. It slightly deviates by including additional details about bike art, which, while related, are not central to the significance of the route itself.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (7):** The model's answer captures the main points about bioaccumulation and harm to developing brain cells, but it inaccurately includes a point about mercury from CFL bulbs contaminating the environment, which is not relevant to the question about coal-burning emissions.
#
# - **Faithfulness (7):** While the answer aligns with much of the context regarding atmospheric mercury release from coal, it introduces an unrelated issue concerning CFL bulb disposal, deviating from the specific focus on coal-related mercury harm.
#
# - **Answer Relevance (9):** The response is largely relevant to the question about potential harm from mercury released by burning coal. However, the inclusion of information about CFL bulbs slightly detracts from its direct relevance.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer is almost entirely correct. It includes all the impressionists mentioned in the context and provides additional details about Sammy Davis Jr.'s specific impressions, which align with the reference answer but adds more depth.
#
# - **Faithfulness (10):** The model accurately reflects the content of the provided context without introducing any inaccuracies or misinterpretations.
#
# - **Answer Relevance (10):** The response directly addresses the question by listing the great impressionists mentioned in the context, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is highly accurate and aligns well with the reference answer. It correctly identifies all five key factors mentioned in the context, which matches closely with the reference answer's points about company match offers, contribution limits, age considerations, personal financial situation, and mindset toward money and risk.
# - **Faithfulness (10):** The model's response is faithful to the provided context. It accurately reflects the details and nuances of the five key factors discussed in the text without introducing any inaccuracies or misinterpretations.
# - **Answer Relevance (10):** The answer directly addresses the question about what factors should be considered when deciding how much to contribute to a 401k retirement plan, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, covering all key points such as management culture, goals and progress tracking, department structure, employee performance review process, company policies, recognitions and rewards, recruiting process, and team budget. However, it slightly deviates by adding "recent developments" which is not explicitly mentioned in the reference.
# - **Faithfulness (9):** The model's answer aligns well with the provided context, accurately reflecting the checklist items for new manager onboarding. It maintains fidelity to the original content while organizing it clearly.
# - **Answer Relevance (10):** The response directly addresses the question about what should be explained to new managers during their onboarding process, making it highly relevant and focused.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer is largely correct and aligns well with the reference answer. It accurately describes what the ACE Score measures and its implications, including the prediction of drug abuse and other problems. However, it slightly deviates by adding Dr. Sandra Bloom's quote about eliminating childhood trauma to reduce drug addiction, which was not part of the reference answer.
#
# - **Faithfulness (9):** The model's response is faithful to the context provided in the text. It correctly extracts information about the ACE Score and its predictive power regarding adverse outcomes due to childhood trauma. The inclusion of Dr. Bloom’s quote adds depth but slightly diverges from the strict content of the reference answer.
#
# - **Answer Relevance (10):** The model's response directly addresses the question about what the ACE Score is and what it predicts, making it highly relevant to the query.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most of the key points such as resistance to pilling, quick drying, stain repelling, and allergen repelling. However, it slightly deviates by mentioning "traditional polyester fabric" instead of focusing solely on cotton.
# - **Faithfulness (9):** The model's response is faithful to the context provided, accurately reflecting the advantages mentioned in the text about microfiber sheets.
# - **Answer Relevance (10):** The answer directly addresses the question regarding the advantages of microfiber sheets over traditional cotton sheets.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer correctly identifies Ginko Biloba and Rosemary as beneficial herbal supplements, but it omits omega-3 fatty acids, which are mentioned in the reference answer. Additionally, while Ginseng is mentioned, its specific benefits like boosting energy and memory are not fully detailed.
#
# - **Faithfulness (9):** The model's response aligns well with the context provided, accurately reflecting the information about Ginko Biloba, Rosemary, and Ginseng. However, it slightly deviates by not mentioning omega-3 fatty acids.
#
# - **Answer Relevance (9):** The answer directly addresses the question regarding herbal supplements beneficial for the brain, but it lacks completeness due to the omission of omega-3 fatty acids.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# ### Explanation:
# - **Answer Correctness (9):** The model's answer is largely correct and aligns well with the reference answer. It accurately describes the cost structure of Ashley Madison's credit system, including specific prices for different quantities of credits and costs associated with messaging and chatting. However, it slightly omits mentioning that sending multimedia gifts can range from 20 to 50 credits.
#
# - **Faithfulness (9):** The model's answer is faithful to the context provided in the reference text. It captures most details accurately without introducing any incorrect information or significant omissions.
#
# - **Answer Relevance (10):** The response directly addresses the question about the cost of Ashley Madison's credit system and how it works, making it highly relevant to the query posed.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 8
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer includes three specific exhibitions and a general category ("Gallery Exhibitions") that was not explicitly listed in the reference. It also misses one exhibition from the reference: "Resilience: The Divine Power of Black & White."
# - **Faithfulness (9):** The information provided is mostly accurate according to the context, but it incorrectly categorizes "Gallery Exhibitions" as a specific type rather than recognizing all listed exhibitions.
# - **Answer Relevance (8):** The answer addresses the question by listing types of art exhibitions, though it includes an unnecessary general category and omits one specific exhibition from the reference.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer by listing charisma, confidence, integrity, inspiration, and excellent personal abilities. However, it slightly deviates in how these traits are described compared to the reference.
# - **Faithfulness (9):** The model accurately reflects the context provided, capturing all mentioned leadership traits with appropriate examples from the text.
# - **Answer Relevance (10):** The answer directly addresses the question about Princess Diana's leadership traits and is relevant throughout.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference answer, with only minor differences in wording and structure. It captures all four circumstances accurately.
# - **Faithfulness (9):** The model's response aligns closely with the context provided, maintaining accuracy and completeness without introducing errors or omissions.
# - **Answer Relevance (10):** The model directly addresses the question about when claims under $5001 can come to Provincial Court, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 8
# }
# ```
#
# **Explanation for Scores:**
#
# - **Answer Correctness (7):** The model's answer includes correct information about the expansion of the panel and monitoring new TV channels. However, it introduces additional details not present in the reference answer, such as cable and satellite penetration rates and reasons for dropping certain stations.
#
# - **Faithfulness (9):** The model accurately reflects most of the context provided, including the increase in panel size and introduction of new channels. It slightly deviates by adding extra information about TV penetration statistics and station drop-off reasons not explicitly required by the question.
#
# - **Answer Relevance (8):** The answer is mostly relevant to the question but includes additional details that were not part of the reference answer, such as cable/satellite penetration rates and specific reasons for dropping certain channels.
#                                                context  \
# 0    Caption: Tasmanian berry grower Nic Hansen sho...
# 1    RWSN Collaborations\nSouthern Africa Self-supp...
# 2    All Android applications categories\nDescripti...
# 3    How unequal is India? The question is simple, ...
# 4    Gunnar Nelson took his time on the feet agains...
# ..                                                 ...
# 995  Last Sunday, as part of a brunch with friends,...
# 996  Printable View\nhow often does Orlando Hire?\n...
# 997  A recent survey of Canadian workers by pension...
# 998  As soon as it hits October I start planning my...
# 999  At some point a couple of weeks ago my blog tu...
#
#                                               question  \
# 0    What is the Berry Export Summary 2028 and what...
# 1    What are some of the benefits reported from ha...
# 2    What are the unique features of the Coolands f...
# 3    What is the main difference between the Nation...
# 4    How did Gunnar Nelson win the fight against Za...
# ..                                                 ...
# 995  What was the unanimous favourite chocolate bar...
# 996  What does the SAFER grant require Orlando to d...
# 997  What percentage of Canadian workers with a tra...
# 998  What type of pears are recommended for making ...
# 999  Why did the author decide to leave Blogger for...
#
#                                                 answer  \
# 0    The Berry Export Summary 2028 is a dedicated e...
# 1    Benefits reported from having access to Self-s...
# 2    The unique features of the Coolands for Twitte...
# 3    The main difference between the NSS and the IH...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  The unanimous favourite was the Organic Cappuc...
# 996  The SAFER grant requires Orlando to replace an...
# 997  50 per cent of workers with a traditional defi...
# 998  Anjou pears, Bosc pears, and Bartlett pears ar...
# 999  The author decided to leave Blogger because it...
#
#                                          answerllama8b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the text, the benefits reported f...
# 2    According to the text, the unique features of ...
# 3    According to the text, the main difference bet...
# 4    According to the text, Gunnar Nelson won the f...
# ..                                                 ...
# 995  According to the text, the unanimous favourite...
# 996  According to the text, the SAFER grant require...
# 997  According to the survey, 50% of workers with a...
# 998  According to the text, the following types of ...
# 999  According to the text, the author decided to l...
#
#                                          answerllama3b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the provided text, the benefits r...
# 2    According to the provided text, the unique fea...
# 3    According to the text, the main difference bet...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  According to the text, the Organic Cappuccino ...
# 996  According to the text, under the SAFER grant, ...
# 997  According to the text, 50% of Canadian workers...
# 998  According to the text, two types of pears are ...
# 999  According to the text, the author left Blogger...
#
#                                       answerGemma3:12b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the text, benefits reported from ...
# 2    According to the provided text, here are the u...
# 3    According to the provided text, the main diffe...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  According to the text, the unanimous favorite ...
# 996  According to the text, the SAFER grant require...
# 997  According to the text, 50 per cent of workers ...
# 998  The text recommends Anjou pears as the ideal c...
# 999  According to the text, the author left Blogger...
#
#      answer_correctness_llama3b  faithfulness  answer_relevance
# 0                             9             9                10
# 1                             9            10                10
# 2                             9             9                10
# 3                             9             9                10
# 4                             9             9                10
# ..                          ...           ...               ...
# 995                           9             9                10
# 996                           9             9                10
# 997                          10            10                10
# 998                           9            10                10
# 999                           9             9                10
#
# [1000 rows x 9 columns]

# %%
import re
import json
import pandas as pd
from typing import Dict
from langchain_ollama.chat_models import ChatOllama
from langchain_core.messages import HumanMessage, SystemMessage

def sanitize_json_string(response_str: str) -> str:
    response_str = response_str.strip()
    if response_str.startswith("```"):
        response_str = re.sub(r"^```(?:\s*json\s*)?\n", "", response_str)
        response_str = re.sub(r"\n```$", "", response_str)
    return response_str
llm2 = ChatOllama(
    model="phi4",  
    temperature=0.0, 
)

def evaluate_answers(context: str, question: str, reference_answer: str, llama_answer: str) -> Dict[str, int]:
    prompt = f"""
You are an expert in evaluating the quality of AI-generated answers. Rate the model's response on a scale from 1 to 10 (1 = Poor, 10 = Excellent). Your evaluation must be extremely strict. Award a score of 10 only when the answer is flawless in every aspect.

Context: {context}
Question: {question}
Reference Answer: {reference_answer}
Model's Answer: {llama_answer}

### Evaluation Criteria
1. Answer Correctness – How precisely the model’s answer matches the reference answer.
2. Faithfulness – Whether the answer aligns accurately with the provided context.
3. Answer Relevance – How directly the answer responds to the question.

Make sure that:
• A score of 10 is only reserved for answers that are completely ideal and without any error.
• Scores below 10 reflect the presence of even minor imperfections or deviations.

Return ONLY a JSON object without any explanation, using one of the following formats:
{{
  "answer_correctness": 8,
  "faithfulness": 6,
  "answer_relevance": 10
}}

"""
    messages = [
        SystemMessage(content="You are an AI evaluation expert. Provide ONLY JSON output"),
        HumanMessage(content=prompt)
    ]
    
    response = llm2.invoke(messages)
    response_str = sanitize_json_string(response.content)
    
    try:
        return json.loads(response_str)
    except json.JSONDecodeError:
        print(f"Parsing error: {response.content}")
        return {
            "answer_correctness": -1,
            "faithfulness": -1,
            "answer_relevance": -1
        }
results = []
for _, row in df.iterrows():
    eval_result = evaluate_answers(
        context=row["context"],
        question=row["question"],
        reference_answer=row["answer"],
        llama_answer=row["answerllama8b"]
    )
    results.append(eval_result)
df_eval = pd.DataFrame(results)
df_final = pd.concat([df_final, df_eval], axis=1)
df_final.rename(columns={'answer_correctness': 'answer_correctness_llama8b'}, inplace=True)
df_final.rename(columns={'faithfulness': 'faithfulness_llama8b'}, inplace=True)
df_final.rename(columns={'answer_relevance': 'answer_relevance_llama8b'}, inplace=True)
print(df_final)
# Out:
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is largely correct and aligns well with the reference answer. It accurately describes the Berry Export Summary 2028 as a dedicated export plan, mentions its goals over the next 10 years, and includes specific targets for strawberry, raspberry, and blackberry exports. However, it slightly deviates by specifying "raspberry and blackberry industries" instead of including strawberries in that part.
# - **Faithfulness (9):** The model's answer is faithful to the context provided. It correctly identifies key elements such as the purpose of the plan, high-opportunity markets, and specific export goals. However, it slightly misrepresents by not mentioning all three berry types together when discussing current positions and goals.
# - **Answer Relevance (10):** The model's answer directly addresses the question about what the Berry Export Summary 2028 is and its purpose, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most of the key steps and responsibilities involved in the routine of an Early Intervention Specialist/Service Coordinator. It includes receiving referrals, initial contact with families, assessing communication skills, discussing hearing exams, scheduling evaluations, coordinating schedules, and providing additional resources. However, it slightly lacks detail on explaining language development expectations for the child's age.
#
# - **Faithfulness (9):** The model accurately reflects the context provided in the original text. It maintains the sequence of actions and responsibilities described by the specialist, ensuring that the essence of their routine is preserved. Minor details such as specific examples of communication skills assessment are included but not exhaustively detailed.
#
# - **Answer Relevance (10):** The answer directly addresses the question about the routine of an Early Intervention Specialist/Service Coordinator. It provides a comprehensive overview of the tasks and responsibilities involved, making it highly relevant to the query.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer is largely correct and aligns well with the reference answer. It captures the essence of reconnecting with feminine power and wisdom, which matches the main theme described in the reference. However, it does not explicitly mention "new levels of consciousness," a specific point from the reference.
#
# - **Faithfulness (9):** The model's response is faithful to the context provided. It accurately reflects the themes discussed in the reviews and endorsements, such as reconnecting with feminine essence, balancing energies, and finding purpose.
#
# - **Answer Relevance (10):** The answer directly addresses the question about the main theme of the book, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, covering all main ingredients and additional components. It includes emollients, thickeners, coloring agents, UV protectants, sweeteners, and preservatives. A minor deduction is made for not explicitly mentioning that different types of lip gloss may have varying main ingredients.
# - **Faithfulness (9):** The model's answer aligns well with the context provided, accurately reflecting the information about lip gloss composition without introducing inaccuracies or omissions.
# - **Answer Relevance (10):** The response directly addresses the question regarding the main ingredients used in lip gloss, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation:
# - **Answer Correctness (9):** The model's answer closely matches the reference, listing most of the correct places and providing additional context about their offerings. However, it slightly deviates by including Honey Pig and Don Dae Gam together as a single entry rather than separate ones.
#
# - **Faithfulness (9):** The response is faithful to the provided context, accurately reflecting the details mentioned in the text about each location's pork belly offerings.
#
# - **Answer Relevance (10):** The answer directly addresses the question by listing specific places where excellent pork belly can be found in Koreatown.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference, with only minor differences in phrasing. For example, "select it by clicking on the circle" instead of "Select that office by clicking on the circle." These are negligible but present.
# - **Faithfulness (9):** The model accurately reflects the context provided without adding or omitting significant information. It maintains the sequence and details as in the reference answer.
# - **Answer Relevance (10):** The response directly addresses the question about the steps to apply for a real estate license through eAccessNY, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer includes several hairstyles mentioned in the context but omits some from the reference answer, such as "short straight hairstyle," "casual short hairstyle," and "asymmetrical layered cut." This results in a score of 7 due to these omissions.
# - **Faithfulness (9):** The model accurately reflects most of the hairstyles described in the context. However, it slightly misrepresents some details, such as not mentioning all aspects like face shape suitability or styling tips for each hairstyle, leading to a score of 9.
# - **Answer Relevance (10):** The answer directly addresses the question about trendy short hairstyles for fall and provides relevant examples from the context, earning a perfect relevance score.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is highly accurate and covers most of the key points mentioned in Haribabu Kommi's email. It includes all major changes listed, such as adding support for storage methods, API hooks, tuple visibility functions, slot-specific routines, and extracting functions into a separate file. However, it slightly misses mentioning the pending comments from Andres and other pending activities.
# - **Faithfulness (9):** The model's answer aligns well with the context provided in the email. It accurately reflects the changes being made to the storage AM as described by Haribabu Kommi. Minor details like pending comments are omitted, but overall faithfulness is high.
# - **Answer Relevance (10):** The response directly addresses the question about what changes are being made to the storage AM according to the email, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 8
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer correctly identifies that specific concerns were not explicitly stated in the text. However, it introduces an assumption about anti-smoking laws without direct evidence from the context.
# - **Faithfulness (9):** The response is mostly faithful to the provided context, acknowledging the lack of explicit details and suggesting a plausible implication based on the overall discussion.
# - **Answer Relevance (8):** The answer addresses the question by discussing the concerns raised but slightly deviates by speculating about anti-smoking laws without direct textual support.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is mostly correct and aligns well with the reference answer. It includes all relevant groups from Section 2.1 but omits some specific family members like mother-in-law, father-in-law, etc., which are mentioned in the context.
# - **Faithfulness (9):** The model accurately reflects the content of the provided context, including additional details about prize winners' eligibility periods from Section 7.4, which adds value to the answer.
# - **Answer Relevance (10):** The response directly addresses who is not eligible to enter competitions, making it highly relevant to the question asked.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is mostly correct and aligns well with the reference. It accurately describes the roles of both the leader and the sweeper, including their responsibilities at junctions. However, it slightly deviates by stating that the marker re-joins in front of the sweeper without explicitly mentioning they pass all other riders except the sweeper.
#
# - **Faithfulness (9):** The model's answer is faithful to the context provided. It correctly interprets and conveys the roles as described, including the distinctive vests for identification.
#
# - **Answer Relevance (10):** The response directly addresses the question about the roles of the leader and sweeper in the Drop-Off System, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely aligns with the reference answer by addressing gender roles and social norms, as well as emphasizing personal comfort and agency. However, it slightly expands on the theme by discussing critical thinking about societal expectations, which is not explicitly mentioned in the reference.
#
# - **Faithfulness (9):** The model accurately reflects the context provided, capturing the essence of Kayla's role reversal and her negotiation within relationships. It remains faithful to the vignette's message but adds a bit more interpretation than strictly necessary.
#
# - **Answer Relevance (10):** The response directly addresses the question about the main theme of the first vignette, making it highly relevant.
# ```
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation for Scores:**
#
# - **Answer Correctness (9):** The model's answer is highly accurate and includes all the key components mentioned in the reference answer. It also adds additional relevant details from the context, such as the area movement map and counters, which are important but not explicitly listed in the reference answer.
#
# - **Faithfulness (9):** The model's response aligns well with the provided context, accurately reflecting the game's mechanics and components. However, it includes more detail than the reference answer, which is beneficial for understanding but slightly deviates from the exact wording of the reference.
#
# - **Answer Relevance (10):** The model's answer directly addresses the question about the key components of Sword of Rome, providing a comprehensive overview that is highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for scores:
# - **Answer Correctness (9):** The model's answer is largely correct and aligns well with the reference answer. It accurately captures the purpose of connecting local artists with tourists and mentions the economic goal. However, it adds a slight nuance by mentioning "products or services," which isn't explicitly stated in the reference.
# - **Faithfulness (9):** The model's response is faithful to the context provided, correctly interpreting the main goals of the Asheville Arts Alive web portal as described. It does not introduce any incorrect information but slightly expands on the idea with additional detail about "products or services."
# - **Answer Relevance (10):** The answer directly addresses the question regarding the purpose of the Asheville Arts Alive web portal, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all key guidelines. However, it slightly rephrases some points and adds a bit more detail in certain areas, which is not present in the reference.
# - **Faithfulness (9):** The model accurately reflects the context provided, maintaining the essence of each guideline without introducing inaccuracies or misinterpretations.
# - **Answer Relevance (10):** The response directly addresses the question about group guidelines and covers all relevant points from the context.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer by listing several of the top insights. However, it does not mention all the points listed in the reference answer, such as social influence, lasting impact, satisfaction, return visitation & recommendation, focus on Generation Z, and post-pandemic conclusions.
# - **Faithfulness (9):** The model's response is faithful to the context provided, accurately reflecting insights from the food travel monitor report. It does not introduce any incorrect information but omits some details present in the reference answer.
# - **Answer Relevance (10):** The model directly addresses the question by listing top insights from the market research reports, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 8,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model correctly identifies that `goodbye()` is called on page unload, but it inaccurately attributes this to server-side action. The function call is client-side JavaScript.
# - **Faithfulness (8):** The answer aligns well with the context provided by mentioning the specific function and its trigger event (`onUnload`), though it misinterprets the mechanism as server-driven.
# - **Answer Relevance (9):** The response directly addresses how the popup was triggered, but slightly misses explaining that this is a client-side JavaScript action rather than a server call.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 8
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer correctly identifies that the specific three things are not explicitly listed in the context. However, it attempts to infer them based on related phrases, which is partially correct but speculative.
# - **Faithfulness (9):** The response aligns well with the context by acknowledging the lack of explicit information and referencing relevant themes from the text.
# - **Answer Relevance (8):** The answer addresses the question directly by discussing the inferred readiness and mindset needed for financial changes, though it could have been more precise in stating that these are not explicitly listed.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer correctly identifies both the last book read and the next one planned to be started. However, it includes additional information about a friend’s comment on the movie adaptation of "The Help," which was not required by the question.
#
# - **Faithfulness (9):** The response is faithful to the context provided in the text. It accurately reflects the details mentioned about both books and includes relevant commentary from the author's friend, although this additional detail wasn't necessary for answering the question.
#
# - **Answer Relevance (10):** The answer directly addresses the question by specifying both the last book read and the next one planned to be started, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer closely aligns with the reference answer by identifying compassion and kindness as central themes. It also mentions the characters' struggles, which is consistent with the context provided. However, it does not explicitly mention "helping others in times of suffering," a phrase from the reference answer.
#
# - **Faithfulness (9):** The model's response accurately reflects the content and sentiment of the review, capturing the essence of how compassion and kindness are portrayed through Daniel and Paloma's experiences. It maintains fidelity to the context by discussing their inner strength and resilience.
#
# - **Answer Relevance (10):** The answer directly addresses the question about the main theme of "Tropical Secrets," making it highly relevant to what was asked.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (7):** The model's answer includes some correct information, such as mentioning La Roche-Posay and Chatellerault. However, it omits several other attractions listed in the reference answer, like heritage sites, remarkable gardens, and Futuroscope.
#
# - **Faithfulness (7):** While the model accurately reflects parts of the context, it fails to include all relevant details from the provided text, such as specific markets and additional tourist attractions.
#
# - **Answer Relevance (9):** The response is largely relevant to the question about popular places near Abilly. It mentions key locations but lacks comprehensive coverage of all notable sites mentioned in the reference answer.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer accurately captures the main points from Dr. Lucky about the origins of American burlesque, including the arrival of Lydia Thompson and the British Blondes in 1868 and the prior existence as a literary parody. However, it omits some details such as the merging with "feminine spectacles" which were part of the reference answer.
# - **Faithfulness (9):** The model's response is faithful to Dr. Lucky’s explanation but lacks completeness by not mentioning the merger with feminine spectacles and its historical context in America, which was included in the reference answer.
# - **Answer Relevance (10):** The model directly addresses the question about the historical origin of American burlesque according to Dr. Lucky, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer correctly identifies three gold medalists from Russia and one from Sweden. However, it omits Alexander Grigoriev, who is mentioned in the reference answer as a gold medalist.
#
# - **Faithfulness (9):** The model accurately reflects the context provided, mentioning Arina Bylinko, Svetlana Nikolaeva, and Victor Gustafsson correctly with their respective details. However, it fails to mention Alexander Grigoriev, which is a minor omission but affects faithfulness slightly.
#
# - **Answer Relevance (10):** The model's answer directly addresses the question about who were the gold medalists on the first day of the FIS Roller Ski World Cup in Khanty-Mansiysk. It provides relevant names and context for each mentioned athlete, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference answer, capturing all key issues Ben DeWitt experiences with his Digitech 2120. It accurately describes the crackling sound and the bypass-like behavior on certain channels.
#
# - **Faithfulness (9):** The model's response aligns closely with the context provided in the text. It faithfully represents the problems described by Ben DeWitt without introducing any inaccuracies or omissions.
#
# - **Answer Relevance (10):** The answer directly addresses the question about the specific problem Ben DeWitt is experiencing, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation:
# - **Answer Correctness (9):** The model's answer is largely correct, providing an accurate description of Calvados and its use in the Apple Sidecar. It correctly identifies Calvados as an apple brandy from France and explains its role in replacing cognac in the cocktail. However, it slightly deviates by adding extra descriptive language not present in the reference.
# - **Faithfulness (9):** The model's answer is faithful to the context provided, accurately reflecting the information about Calvados and its application in the Apple Sidecar recipe. It maintains the essence of the original text while providing a clear explanation.
# - **Answer Relevance (10):** The response directly addresses the question regarding what Calvados is and how it is used in the context of the Sidecar cocktail, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer but includes additional context about leveraging innovation and technology, which is not explicitly part of the reference answer.
# - **Faithfulness (9):** The model accurately reflects the information provided in the context, though it adds extra details beyond what was directly asked for.
# - **Answer Relevance (10):** The response directly addresses the question regarding the purpose of the EETT program.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all key steps and providing additional context where appropriate. A minor deduction is made because it includes some extra details not explicitly mentioned in the reference.
# - **Faithfulness (9):** The response aligns well with the provided context, accurately reflecting the content and intent of the original text. It maintains the essence while adding slight elaboration for clarity.
# - **Answer Relevance (10):** The model's answer directly addresses the question about steps to get a book published, making it highly relevant and focused on the query.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer partially aligns with the reference answer by mentioning that constant attention from the mother might be why the child seeks her attention. However, it diverges by incorporating additional perspectives not present in the reference answer.
#
# - **Faithfulness (5):** While the model captures some elements of the context, such as the child's need for love and approval, it introduces interpretations that are not explicitly supported by the reference answer or directly stated in the provided text.
#
# - **Answer Relevance (9):** The model's response is relevant to the question about why a child seeks attention from their mother. It addresses potential reasons related to seeking love and approval, which aligns with the core inquiry of the question.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer closely matches the reference answer by identifying key concerns such as entrance/exit issues, crash test safety, design flaws, and practicality. However, it does not explicitly mention the lack of air conditioning or where to keep groceries/baggage, which are part of the reference answer.
#
# - **Faithfulness (9):** The model's response is faithful to the context provided in the comments. It accurately captures concerns raised by different commenters about the car design.
#
# - **Answer Relevance (10):** The model directly addresses the question regarding concerns about the 'Low Resistance Mobile' car design, making it highly relevant.
# ```
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer includes the correct number of dogs adopted by Decker P. but adds unnecessary speculation about the second dog, which is not required or supported by the context.
# - **Faithfulness (5):** The addition of speculative information about the breed of the second dog deviates from the provided context and introduces potential inaccuracies.
# - **Answer Relevance (9):** The answer directly addresses the question but includes extraneous details that are not relevant to confirming the number of dogs adopted.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 8
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (7):** The model's answer correctly identifies b-roll clips and photos but omits reports and fact sheets, which are part of the reference answer. This omission results in a score less than perfect.
#
# - **Faithfulness (9):** The model accurately reflects the content provided in the context regarding available media types like b-roll clips and photos. However, it misses some details such as reports and fact sheets.
#
# - **Answer Relevance (8):** The answer is relevant to the question about the type of media available but lacks completeness by not mentioning all categories listed in the reference answer.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation for Scores:**
#
# - **Answer Correctness (9):** The model's answer is almost entirely correct. It accurately identifies the series as "Planet Earth Live" and mentions its broadcast in 140 countries, starting on May 6th, with real-time tracking of animals in HD. However, it omits the detail about the series airing every Thursday and Sunday for three weeks.
#
# - **Faithfulness (9):** The model's answer is faithful to the context provided. It correctly captures the essence of the broadcast plan and its global reach. The omission of specific airing days slightly affects faithfulness but does not significantly alter the overall accuracy.
#
# - **Answer Relevance (10):** The model's response directly addresses the question about what the BBC's "most ambitious global wildlife series ever" is and how it is being broadcasted, making it highly relevant.
# ```
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is mostly correct and aligns well with the reference answer. It correctly identifies performance and documentation as major goals, along with specific improvements like SmartServer extension and file system optimizations. However, it includes additional details not explicitly mentioned in the reference answer.
#
# - **Faithfulness (9):** The model accurately reflects the context provided, including relevant details about performance enhancements and documentation efforts. It stays true to the information given without introducing inaccuracies.
#
# - **Answer Relevance (10):** The response directly addresses the question regarding major feature goals for Bazaar 1.0, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference, with a minor error in stating that ROYDAN uses an "account-centric model" instead of a "consumer-centric approach." This small deviation affects correctness slightly.
# - **Faithfulness (9):** The response accurately reflects the context provided, capturing all key points except for the minor misstatement about the consumer-centric approach.
# - **Answer Relevance (10):** The answer directly addresses the question and includes all relevant aspects of what sets ROYDAN apart.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# **Explanation of Scores:**
#
# - **Answer Correctness (7):** The model's answer incorrectly states that the author rejects the idea that the NAACP has outlived its usefulness, whereas the reference answer clearly indicates that the author believes it has. This is a significant deviation from the correct interpretation.
#
# - **Faithfulness (5):** While the model captures some elements of the context, such as the criticism and loss of credibility attributed to the NAACP by the author, it misrepresents the core opinion about the organization's usefulness. The statement that the author "strongly criticizes and rejects" the idea is incorrect.
#
# - **Answer Relevance (9):** The model’s answer directly addresses the question regarding the author's opinion about the NAACP, making it highly relevant to the query posed. However, due to inaccuracies in capturing the author's stance, a perfect score cannot be awarded.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation:
# - **Answer Correctness (9):** The model's answer is mostly correct but includes an additional type ("Groups") that was not explicitly listed in the reference answer. However, it does accurately describe all types mentioned in the context.
# - **Faithfulness (9):** The model's response aligns well with the provided context and accurately describes each stock list item type as per the context.
# - **Answer Relevance (10):** The model directly addresses the question about different types of stock list items, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is very close to the reference answer, capturing the essence of the author's opinion about grafting. It mentions the challenge and need for instructions, aligning well with the reference. However, it slightly lacks the mention that the task took only 10 minutes, which was part of the reference.
# - **Faithfulness (10):** The model accurately reflects the context provided in the text regarding the author's opinion on grafting.
# - **Answer Relevance (10):** The answer directly addresses the question about the author's opinion on grafting the toes.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is largely correct and aligns well with the reference answer. It mentions assisting local businesses, accelerating economic recovery, increasing public safety, furthering economic policies, and capitalizing on "next-normal" opportunities. However, it does not explicitly mention providing links to resources or contact forms for assistance, which are part of the reference answer.
# - **Faithfulness (9):** The model's response is faithful to the context provided in the text. It accurately reflects the purpose of the website as described, though it omits some specific details like the inclusion of links and contact forms.
# - **Answer Relevance (9):** The model's answer directly addresses the question about the purpose of the new website. However, it could have been more comprehensive by including all elements mentioned in the reference answer.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most of the key benefits mentioned. However, it omits some details such as the specific mention of Vanessa being Pet Tech First Aid certified and her ability to administer first aid or perform CPR.
#
# - **Faithfulness (9):** The model accurately reflects the context provided in the text, including the main points about staying at home, routine maintenance, personalized care, security, reduced disease exposure, and emergency vet access. It also correctly mentions Vanessa's recommendations for catteries.
#
# - **Answer Relevance (10):** The answer directly addresses the question by listing the benefits of using Gold Coast Pet Sitting services over boarding in catteries or kennels, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer by listing difficulty sleeping and changes in medical condition as reasons to consider buying a new bed. However, it omits mentioning pain or discomfort specifically when in the current bed.
# - **Faithfulness (9):** The model accurately reflects the context provided, capturing key points about sleep difficulties and medical conditions without introducing inaccuracies.
# - **Answer Relevance (10):** The answer directly addresses the question by listing reasons to consider buying a new bed, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, covering most of the key points such as omega-3 fatty acids, vitamin B6, garlic, and flavonoid-rich extracts. However, it omits some details like specific dosages for fish oil supplements in certain conditions and other helpful supplements mentioned in the context.
#
# - **Faithfulness (9):** The model's answer is faithful to the provided context, accurately reflecting the information about natural ways to prevent excessive platelet aggregation and reduce heart disease risk. It does not introduce any incorrect or misleading information.
#
# - **Answer Relevance (10):** The model's response directly addresses the question by listing specific natural methods for preventing excessive platelet aggregation and reducing heart disease and stroke risks, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing the main points about setting measurable goals in January and acknowledging that things may not go as planned. However, it slightly omits mentioning the contemplation of a yearly scripture.
#
# - **Faithfulness (9):** The response is faithful to the context provided, accurately reflecting the author's practices without introducing inaccuracies or misinterpretations.
#
# - **Answer Relevance (10):** The model's answer directly addresses the question about the author's practice for setting goals and resolutions, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, accurately listing attempt liability, solicitation liability, and contribution to the commission or attempted commission of a war crime as specified in Article 25(b), (f), and (d) respectively. A minor deduction is made because the explanation could be more concise by directly referencing "Article 25" without repeating its content.
#
# - **Faithfulness (9):** The model's answer faithfully represents the information provided in the context, correctly identifying the relevant articles of the Rome Statute. It maintains accuracy and does not introduce any incorrect or misleading information.
#
# - **Answer Relevance (10):** The response directly addresses the question about what the Rome Statute includes in terms of liability for war crimes, making it highly relevant to the query.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer includes the correct product ("glitter liner") that kj is looking forward to trying, but it also unnecessarily mentions other products and details about Sherry's wishlist. This adds information not directly asked for in the question.
#
# - **Faithfulness (7):** The response aligns with the context provided by mentioning the glitter liner as a product of interest. However, it includes additional commentary that was not required, slightly deviating from the core focus.
#
# - **Answer Relevance (9):** The answer is relevant to the question about what kj is looking forward to trying, but it could be more concise and focused solely on the specific item mentioned in the reference answer.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is mostly correct and aligns well with the reference answer. It includes most of the key features mentioned in both the context and the reference answer, such as the seat belt, wheel locks, storage plate, folding design, control capabilities, and hill-climbing ability. However, it omits some details like weight capacity (up to 265 pounds) and speed (up to 5 mph), which are present in the reference answer.
# - **Faithfulness (9):** The model's response is faithful to the context provided. It accurately reflects the features described in the text without introducing any incorrect information or omitting critical details that would mislead the reader.
# - **Answer Relevance (10):** The model's answer directly addresses the question about the features of the KD Wise Seat electric wheelchair, making it highly relevant and focused on the query.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer captures an important aspect of the context but does not fully align with the reference answer, which emphasizes understanding from the other person's point of view.
# - **Faithfulness (5):** While the model's response is related to the context, it focuses more on the dynamics of communication rather than the specific emphasis on understanding the theme or situation from another perspective as highlighted in the reference answer.
# - **Answer Relevance (9):** The model's answer addresses a relevant aspect of effective communication but does not fully capture the essence of the reference answer.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all key practices mentioned. It includes understanding client needs, establishing a revision system, signing contracts, being honest and diplomatic, and choosing clients carefully. A minor deduction is made because it slightly rephrases some points but does not miss any critical information.
# - **Faithfulness (9):** The model's answer accurately reflects the context provided in the reference text. It maintains the essence of each practice described without introducing inaccuracies or omissions, aside from slight rewording.
# - **Answer Relevance (10):** The response directly addresses the question about best practices to avoid unnecessary revisions and conflicts, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost perfectly aligned with the reference answer, capturing all exceptions accurately. It includes an additional detail about 1-to-1 Projects not being covered by the guarantee, which was mentioned in the context but not explicitly required by the question.
# - **Faithfulness (10):** The response faithfully represents the information provided in the context without any distortion or omission of critical details related to the exceptions.
# - **Answer Relevance (10):** The answer directly addresses the question about exceptions to the money-back guarantee, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer closely matches the reference answer by accurately describing Ash Wednesday and Fat Tuesday in Roman Catholic tradition. It includes details about Lent, penitence, restraint, and the indulgence of Mardi Gras. However, it adds a brief mention of ashes symbolizing life as dust from Matthew 5:4, which is not present in the reference answer.
#
# - **Faithfulness (9):** The model's response aligns well with the context provided, accurately reflecting the traditions and their significance. It maintains the critical perspective on indulgence before Lent but does not deviate significantly from the factual content of the tradition itself.
#
# - **Answer Relevance (10):** The answer directly addresses the question about the significance of Ash Wednesday and Fat Tuesday in Roman Catholic tradition, making it highly relevant to the query.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9)**: The model's answer is almost identical to the reference, with all key features accurately mentioned. However, there is a minor typographical error ("Thowing" instead of "Throwing").
# - **Faithfulness (9)**: The model faithfully represents the information from the context without adding or omitting significant details.
# - **Answer Relevance (10)**: The answer directly addresses the question about the features of the snow thrower.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model correctly identifies Iga Swiatek as one of the players Sakkari defeated. However, it incorrectly suggests that Aryna Sabalenka might be a player she has beaten and introduces Paulina Badosa without clear evidence from the text.
#
# - **Faithfulness (5):** The answer includes assumptions not directly supported by the context, such as suggesting Sabalenka or Badosa as potential victories for Sakkari. This deviates from the provided information.
#
# - **Answer Relevance (9):** The model's response is mostly relevant to the question but introduces unnecessary speculation about other players, slightly detracting from its directness.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer by addressing both sides of the controversy: those wanting complete reconstruction and those fearing it will become a historic Disneyland. It also includes additional context about criticisms from specific individuals, which enriches the response without deviating from the core issue.
#
# - **Faithfulness (9):** The model's answer is faithful to the provided context, accurately reflecting the split opinions and including relevant quotes and perspectives from key figures like Jürgen E. Aha and Philipp Oswalt.
#
# - **Answer Relevance (10):** The response directly addresses the question about the main controversy surrounding the reconstruction project, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is mostly correct but omits some details from the reference answer, such as children turning 13 before May 26, 2011, and those starting camp after July 1, 2011, being ineligible.
# - **Faithfulness (9):** The model accurately reflects the context provided in the text. However, it misses a few specific eligibility criteria mentioned in the reference answer.
# - **Answer Relevance (10):** The model's response directly addresses the question about who is eligible for tuition assistance, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 8,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer is mostly correct but introduces an interpretation that isn't explicitly supported by the text. It suggests treating claims of being gay due to inherent nature similarly to other sincerely held beliefs, which adds a layer not directly stated in the context.
#
# - **Faithfulness (8):** The response aligns well with the provided context, accurately reflecting the EEOC's stance on "gayness" as a belief system or personal preference. However, it slightly deviates by interpreting inherent nature claims without explicit backing from the text.
#
# - **Answer Relevance (9):** The answer is highly relevant to the question, addressing the employer's responsibility in relation to an employee's claim of being gay due to their inherent nature. It stays on topic and provides a thoughtful interpretation based on the context.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost entirely correct, matching the reference answer closely. It includes all key points about who delivered the helicopter and its operational capabilities. However, it adds a bit more detail than the reference answer by mentioning optional equipment.
#
# - **Faithfulness (9):** The model accurately reflects the information provided in the context. All details included are present in the original text, with no significant deviations or inaccuracies.
#
# - **Answer Relevance (10):** The response directly addresses the question about who delivered the helicopter and its operational capabilities, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer by detailing the steps to obtain jail records, including visiting the Registry of Criminal Records and contacting them directly. However, it includes additional information about rules at the jail that is not part of the reference answer.
#
# ...
#
# - **Faithfulness (9):** The model accurately reflects the content provided in the context without introducing inaccuracies or irrelevant information. It maintains the essence of the services described.
#
# - **Answer Relevance (10):** The answer directly addresses the question about the services provided by the biohazard cleanup company, making it highly relevant and focused on the query.
# ```
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is mostly correct and includes all roles mentioned in the reference answer, with additional relevant details. However, it slightly deviates by including more specific information than required.
# - **Faithfulness (9):** The model accurately reflects the context provided, but adds extra detail about his first job at CKSO which was not explicitly requested.
# - **Answer Relevance (10):** The answer directly addresses the question regarding Bill Catalano's roles at CKSO.
# Parsing error: ```json
# {
#   "answer_correctness": 2,
#   "faithfulness": 9,
#   "answer_relevance": 7
# }
# ```
#
# Explanation:
# - **Answer Correctness (2):** The model's answer incorrectly identifies the "Pose'N Supply" bottle as the "Twist'N Feed" bottle, which is a significant error. The reference answer specifies that there is no mention of the "Twist'N Feed" bottle in the text.
#
# - **Faithfulness (9):** The model accurately describes the "Pose'N Supply" bottle based on the provided context, maintaining faithfulness to the information given.
#
# - **Answer Relevance (7):** While the model addresses a similar product ("Pose'N Supply"), it does not directly answer the question about the "Twist'N Feed" bottle. However, it acknowledges that there is no mention of such a bottle in the text, which partially aligns with the relevance to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all key points from each review. However, it slightly deviates by not explicitly mentioning Gail k.'s implied dissatisfaction.
# - **Faithfulness (9):** The response accurately reflects the context provided in the reviews, maintaining the essence of each customer's feedback without introducing inaccuracies.
# - **Answer Relevance (10):** The model directly addresses the question about the reviews, providing a clear and relevant summary for each review.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation for Scores:**
#
# - **Answer Correctness (9):** The model's answer is highly accurate and aligns closely with the reference answer. It includes all major requirements such as age, education level, interest in healthcare, personal attributes, application process details, health screening, and orientation training. However, it slightly deviates by specifying that an interest in a healthcare career is not a requirement, which could be interpreted differently from "interested in or considering a career in healthcare."
#
# - **Faithfulness (9):** The model's answer faithfully represents the context provided. It captures all essential elements of the internship requirements and application process. The minor deviation regarding the necessity of an interest in a healthcare career does not significantly detract from its overall faithfulness.
#
# - **Answer Relevance (10):** The response directly addresses the question about the requirements for the internships, making it highly relevant to the query posed.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 8
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer includes additional information about pre-registration and T-shirts, which is not part of the specific question regarding packet pickup times and locations. This introduces minor inaccuracies.
# - **Faithfulness (9):** The model accurately reflects most details from the context but adds unnecessary information about pre-registration and T-shirts.
# - **Answer Relevance (8):** While relevant to the topic, the answer includes extra details not directly asked for in the question, slightly reducing its relevance.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most key features accurately. However, it repeats "inbuilt check valve" unnecessarily and omits mentioning the installation kit.
# - **Faithfulness (9):** The response aligns well with the provided context but misses some details like the inclusion of an installation kit.
# - **Answer Relevance (10):** The answer directly addresses the question about features, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer correctly identifies the impressionists mentioned in the context, including Sammy Davis Jr., Rich Little, Frank Caliendo, Kevin Spacey, Pablo Francisco, and Dean Edwards. It matches closely with the reference answer but provides additional details about each individual, which is not necessary for correctness but adds value.
#
# - **Faithfulness (10):** The model's response accurately reflects the information provided in the context without introducing any inaccuracies or misinterpretations.
#
# - **Answer Relevance (10):** The model directly addresses the question by listing the great impressionists mentioned in the context, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference answer, with only a minor difference in formatting. The order of names and instruments is slightly different but does not affect correctness.
# - **Faithfulness (10):** The model accurately reflects the information provided in the context without any distortion or omission.
# - **Answer Relevance (10):** The response directly addresses the question about the members of the Sitkovetsky Piano Trio.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, covering all key points. However, it adds a point about recent changes or updates which is not explicitly mentioned in the reference.
# - **Faithfulness (9):** The response aligns well with the context provided, accurately reflecting the checklist and additional details given.
# - **Answer Relevance (10):** The answer directly addresses the question regarding what should be explained to new managers during their onboarding process.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is largely correct and aligns well with the reference answer. It accurately lists Ginko Biloba, Rosemary, Ginseng, and mentions omega-3 fatty acids as beneficial supplements. However, it omits a direct mention of omega-3 fatty acids in the list, which are included in the reference answer.
#
# - **Faithfulness (9):** The model's response is faithful to the context provided. It accurately reflects the information about each supplement and their effects on brain health as described in the text.
#
# - **Answer Relevance (10):** The model's answer directly addresses the question by listing herbal supplements beneficial for the brain and describing their effects, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# ### Explanation:
# - **Answer Correctness (9):** The model's answer is mostly correct and aligns well with the reference answer. It accurately describes the cost structure for credits, messaging, and live chat. However, it omits some details about additional costs after the first hour of chatting.
#
# - **Faithfulness (9):** The model's response is faithful to the context provided in the text. It correctly extracts and presents information regarding credit pricing and usage.
#
# - **Answer Relevance (10):** The answer directly addresses the question about the cost of Ashley Madison's credit system and how it works, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is mostly correct and aligns well with the reference answer. It accurately mentions the expansion of households, introduction of combined data research, and monitoring of new channels. However, it includes additional details about discontinuing TV Puls and Tele 5, which were not part of the specific changes asked in the question.
# - **Faithfulness (9):** The model's response is faithful to the context provided, accurately reflecting the information from the text. It correctly identifies key changes but adds extra information that was not explicitly required by the question.
# - **Answer Relevance (10):** The answer directly addresses the question about changes implemented in January 2003, making it highly relevant.
#                                                context  \
# 0    Caption: Tasmanian berry grower Nic Hansen sho...
# 1    RWSN Collaborations\nSouthern Africa Self-supp...
# 2    All Android applications categories\nDescripti...
# 3    How unequal is India? The question is simple, ...
# 4    Gunnar Nelson took his time on the feet agains...
# ..                                                 ...
# 995  Last Sunday, as part of a brunch with friends,...
# 996  Printable View\nhow often does Orlando Hire?\n...
# 997  A recent survey of Canadian workers by pension...
# 998  As soon as it hits October I start planning my...
# 999  At some point a couple of weeks ago my blog tu...
#
#                                               question  \
# 0    What is the Berry Export Summary 2028 and what...
# 1    What are some of the benefits reported from ha...
# 2    What are the unique features of the Coolands f...
# 3    What is the main difference between the Nation...
# 4    How did Gunnar Nelson win the fight against Za...
# ..                                                 ...
# 995  What was the unanimous favourite chocolate bar...
# 996  What does the SAFER grant require Orlando to d...
# 997  What percentage of Canadian workers with a tra...
# 998  What type of pears are recommended for making ...
# 999  Why did the author decide to leave Blogger for...
#
#                                                 answer  \
# 0    The Berry Export Summary 2028 is a dedicated e...
# 1    Benefits reported from having access to Self-s...
# 2    The unique features of the Coolands for Twitte...
# 3    The main difference between the NSS and the IH...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  The unanimous favourite was the Organic Cappuc...
# 996  The SAFER grant requires Orlando to replace an...
# 997  50 per cent of workers with a traditional defi...
# 998  Anjou pears, Bosc pears, and Bartlett pears ar...
# 999  The author decided to leave Blogger because it...
#
#                                          answerllama8b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the text, the benefits reported f...
# 2    According to the text, the unique features of ...
# 3    According to the text, the main difference bet...
# 4    According to the text, Gunnar Nelson won the f...
# ..                                                 ...
# 995  According to the text, the unanimous favourite...
# 996  According to the text, the SAFER grant require...
# 997  According to the survey, 50% of workers with a...
# 998  According to the text, the following types of ...
# 999  According to the text, the author decided to l...
#
#                                          answerllama3b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the provided text, the benefits r...
# 2    According to the provided text, the unique fea...
# 3    According to the text, the main difference bet...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  According to the text, the Organic Cappuccino ...
# 996  According to the text, under the SAFER grant, ...
# 997  According to the text, 50% of Canadian workers...
# 998  According to the text, two types of pears are ...
# 999  According to the text, the author left Blogger...
#
#                                       answerGemma3:12b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the text, benefits reported from ...
# 2    According to the provided text, here are the u...
# 3    According to the provided text, the main diffe...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  According to the text, the unanimous favorite ...
# 996  According to the text, the SAFER grant require...
# 997  According to the text, 50 per cent of workers ...
# 998  The text recommends Anjou pears as the ideal c...
# 999  According to the text, the author left Blogger...
#
#      answer_correctness_llama3b  faithfulness_llama3b  \
# 0                             9                     9
# 1                             9                    10
# 2                             9                     9
# 3                             9                     9
# 4                             9                     9
# ..                          ...                   ...
# 995                           9                     9
# 996                           9                     9
# 997                          10                    10
# 998                           9                    10
# 999                           9                     9
#
#      answer_relevance_llama3b  answer_correctness_llama8b  \
# 0                          10                          -1
# 1                          10                           9
# 2                          10                           9
# 3                          10                           9
# 4                          10                           9
# ..                        ...                         ...
# 995                        10                           9
# 996                        10                           9
# 997                        10                          10
# 998                        10                           9
# 999                        10                           9
#
#      faithfulness_llama8b  answer_relevance_llama8b
# 0                      -1                        -1
# 1                      10                        10
# 2                       9                        10
# 3                       9                        10
# 4                      10                        10
# ..                    ...                       ...
# 995                     9                        10
# 996                     9                        10
# 997                    10                        10
# 998                    10                        10
# 999                     9                        10
#
# [1000 rows x 12 columns]

# %%
import re
import json
import pandas as pd
from typing import Dict
from langchain_ollama.chat_models import ChatOllama
from langchain_core.messages import HumanMessage, SystemMessage

def sanitize_json_string(response_str: str) -> str:
    response_str = response_str.strip()
    if response_str.startswith("```"):
        response_str = re.sub(r"^```(?:\s*json\s*)?\n", "", response_str)
        response_str = re.sub(r"\n```$", "", response_str)
    return response_str
llm2 = ChatOllama(
    model="phi4",  
    temperature=0.0, 
)

def evaluate_answers(context: str, question: str, reference_answer: str, llama_answer: str) -> Dict[str, int]:
    prompt = f"""
You are an expert in evaluating the quality of AI-generated answers. Rate the model's response on a scale from 1 to 10 (1 = Poor, 10 = Excellent). Your evaluation must be extremely strict. Award a score of 10 only when the answer is flawless in every aspect.

Context: {context}
Question: {question}
Reference Answer: {reference_answer}
Model's Answer: {llama_answer}

### Evaluation Criteria
1. Answer Correctness – How precisely the model’s answer matches the reference answer.
2. Faithfulness – Whether the answer aligns accurately with the provided context.
3. Answer Relevance – How directly the answer responds to the question.

Make sure that:
• A score of 10 is only reserved for answers that are completely ideal and without any error.
• Scores below 10 reflect the presence of even minor imperfections or deviations.

Return ONLY a JSON object without any explanation, using one of the following formats:
{{
  "answer_correctness": 8,
  "faithfulness": 6,
  "answer_relevance": 10
}}

"""
    messages = [
        SystemMessage(content="You are an AI evaluation expert. Provide ONLY JSON output"),
        HumanMessage(content=prompt)
    ]
    
    response = llm2.invoke(messages)
    response_str = sanitize_json_string(response.content)
    
    try:
        return json.loads(response_str)
    except json.JSONDecodeError:
        print(f"Parsing error: {response.content}")
        return {
            "answer_correctness": -1,
            "faithfulness": -1,
            "answer_relevance": -1
        }
results = []
for _, row in df.iterrows():
    eval_result = evaluate_answers(
        context=row["context"],
        question=row["question"],
        reference_answer=row["answer"],
        llama_answer=row["answerGemma3:12b"]
    )
    results.append(eval_result)
df_eval = pd.DataFrame(results)
df_final = pd.concat([df_final, df_eval], axis=1)
df_final.rename(columns={'answer_correctness': 'answer_correctness_answerGemma3:12b'}, inplace=True)
df_final.rename(columns={'faithfulness': 'faithfulness_answerGemma3:12b'}, inplace=True)
df_final.rename(columns={'answer_relevance': 'answer_relevance_answerGemma3:12b'}, inplace=True)
print(df_final)
# Out:
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most of the key features mentioned. However, it does not explicitly mention that they are suitable to wear during the day and at night, which is a minor omission.
# - **Faithfulness (10):** The model accurately reflects the information provided in the context without introducing any inaccuracies or extraneous details.
# - **Answer Relevance (10):** The answer directly addresses the question about the features of Fabiana Filippi's shirts and blouses.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all four strategies mentioned. However, it includes additional context about AnswerNow that was not part of the reference answer.
# - **Faithfulness (9):** The response is faithful to the provided context and accurately reflects the content, though it adds extra information about AnswerNow which slightly deviates from the core focus on strategies alone.
# - **Answer Relevance (10):** The model's answer directly addresses the question by listing the strategies for improving call center efficiency and effectiveness.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer but omits the additional caution about hosts being legally responsible for their guests' actions after they leave the party.
# - **Faithfulness (9):** The model accurately reflects the main points from the context, though it misses some details present in the full context.
# - **Answer Relevance (10):** The response directly addresses the question regarding advice given to hosts by the NYIA.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost perfect, capturing all items listed in the reference answer. However, it omits the bright lipstick, which was included in the reference.
# - **Faithfulness (9):** The response accurately reflects the context provided, including additional relevant details like the favorite toy and goldfish crumbs.
# - **Answer Relevance (10):** The model's answer directly addresses the question about what items are carried for the toddler.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost perfect but omits the "Consult with Us" program mentioned in the reference answer.
# - **Faithfulness (9):** The model accurately reflects the context provided, listing most of the programs correctly and describing them well. However, it misses one program from the full list.
# - **Answer Relevance (10):** The response directly addresses the question about volunteer opportunities at EATS, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference, with only minor differences in wording and structure. For example, it omits the phrase "Then click 'Next Step' to continue" after some steps, which are present in the reference.
# - **Faithfulness (9):** The model accurately reflects the context provided, including all necessary steps and additional information about broker authorization.
# - **Answer Relevance (10):** The answer directly addresses the question by listing the steps required for applying through eAccessNY.
# Parsing error: ```json
# {
#   "answer_correctness": 5,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation:
# - **Answer Correctness (5):** The model's answer identifies the IBM Thinkpad as an i1400, which is correct but does not directly address the question about the name of the Thinkpad. The reference answer specifies that the name is "Al-Rassan," which the model fails to mention.
#
# - **Faithfulness (7):** The model accurately extracts information from the context regarding the IBM Thinkpad i1400, showing a good understanding of the text but not fully aligning with the specific question asked.
#
# - **Answer Relevance (9):** The answer is relevant as it pertains to the IBM Thinkpad mentioned in the context. However, it does not directly address the name "Al-Rassan," which was specifically requested by the question.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is highly accurate and aligns closely with the reference answer. It includes all key points from the context, such as port charges in hard currency, invoice requirements, bank account specifications, payment options, currency for other goods and services, and restrictions on offshore accounts. However, there is a minor typographical error ("expect" instead of "except") which prevents a perfect score.
# - **Faithfulness (9):** The model's answer faithfully represents the context provided, accurately reflecting the terms and conditions outlined in Order No. 2/21. It maintains the integrity of the original information with only a slight typographical issue noted above.
# - **Answer Relevance (10):** The response directly addresses the question about the new terms and conditions for settlement, making it highly relevant to the query posed.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is highly accurate and covers most of the features mentioned in the reference answer. However, it slightly rephrases some points and omits mentioning that kPow integrates with specific providers like Okta, Github SSO, AWS SSO, and Azure AD.
# - **Faithfulness (9):** The response aligns well with the provided context, accurately reflecting the features described in the product overview. It maintains fidelity to the original text but could have included more explicit mention of some integration details.
# - **Answer Relevance (10):** The model's answer directly addresses the question about kPow's features and is highly relevant to the query posed.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference answer, with a minor difference in phrasing ("½ cup agave syrup" vs. "½ cup agave or maple syrup"). This slight deviation does not affect the overall correctness significantly.
# - **Faithfulness (10):** The model accurately reflects all ingredients listed in the context without any omissions or additions.
# - **Answer Relevance (10):** The response directly addresses the question by listing the required ingredients, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer but omits the guideline of "honoring commitments" and slightly rephrases "being 'all in'" as "attentive presence."
# - **Faithfulness (9):** The model accurately reflects most aspects of the context, though it misses one guideline.
# - **Answer Relevance (10):** The answer directly addresses the question about group guidelines.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is very close to the reference, capturing all key elements such as Kevin James' dual role, the mistaken identity due to his novel being published as nonfiction, and his kidnapping in Venezuela. However, it slightly lacks the detail about him being ordered to kill "Corrupt Person A" multiple times.
# - **Faithfulness (9):** The model's answer aligns well with the context provided, accurately reflecting the main plot points without introducing inaccuracies or omissions that would significantly alter the understanding of the movie's events.
# - **Answer Relevance (10):** The response directly addresses the question about what happens to Kevin James' character in the film, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is highly accurate and aligns well with the reference answer. It includes all major points from the context, such as attractive content, Facebook advertising, sharing opportunities, organic sharing, and relationship building. However, it does not explicitly mention the increase in "likes" or the specific number of attendees at gatherings, which are minor omissions.
# - **Faithfulness (9):** The model's answer is faithful to the context provided. It accurately reflects the strategies used by the USAID program as described in the text. The only slight deviation is the omission of some specific details like the exact increase in "likes" and the number of attendees at gatherings, but these do not significantly alter the overall message.
# - **Answer Relevance (10):** The model's answer directly addresses the question about how the USAID program increased its visibility and engagement through social media. It is relevant and comprehensive, covering all key strategies mentioned in the context.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer correctly identifies that the function was called when the user left the site, aligning with the context. However, it does not explicitly mention server-side involvement or clarify how this is technically achieved without additional details.
#
# - **Faithfulness (7):** The response accurately reflects the user's experience as described in the context but lacks depth regarding technical implementation, which was implied by the question about server-side functionality.
#
# - **Answer Relevance (9):** The answer directly addresses the question of how the function was called when leaving the site. It is relevant and on-topic, though it could have been more comprehensive in explaining potential mechanisms like server-side scripts or JavaScript events.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 8
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (7):** The model's answer includes several popular places to visit near Abilly, but it omits some details from the reference answer such as markets and other attractions like Les jardins du château de Villandry and Parc et jardins du château de Chenonceau. It also incorrectly lists Brenne as a heritage site instead of a regional natural park.
#
# - **Faithfulness (9):** The model's answer is mostly faithful to the context, accurately listing several places mentioned in the provided text. However, it slightly misclassifies some attractions and omits others.
#
# - **Answer Relevance (8):** The response directly addresses the question about popular places to visit near Abilly but lacks completeness by omitting certain attractions listed in the reference answer.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing key points such as the year 1868, Lydia Thompson and the British Blondes, and the merging with "feminine spectacles." However, it slightly omits the detail about burlesque being a subset of literary parody that inverts form and content.
# - **Faithfulness (9):** The model's answer is faithful to the context provided by Dr. Lucky, accurately reflecting his explanation without introducing inaccuracies or misinterpretations.
# - **Answer Relevance (10):** The model's response directly addresses the question about the historical origin of American burlesque according to Dr. Lucky, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost perfect but misses mentioning "Psyllium Free," which was included in the reference answer.
# - **Faithfulness (10):** The information provided by the model aligns accurately with the context given, except for the missing detail about Psyllium.
# - **Answer Relevance (10):** The response directly addresses the question regarding dietary needs.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer correctly states that hydrogen gas increases productivity, but it does not mention the specific detail about tripling biomass yield at lower light intensity or the necessity of both light and H-2 for growth.
# - **Faithfulness (9):** The model accurately reflects the context by mentioning the increase in productivity with H-2. However, it lacks some specifics from the reference answer.
# - **Answer Relevance (10):** The response directly addresses the question about the effect of hydrogen gas on productivity.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all key steps and details. A minor deduction is made because it includes additional context about the second draft that was not explicitly required by the question.
# - **Faithfulness (9):** The model accurately reflects the content of the provided text, maintaining fidelity to the original information without introducing errors or omissions.
# - **Answer Relevance (10):** The answer directly addresses the question and provides a clear list of steps for getting a book published, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (7):** The model's answer captures several key points from the reference, such as needing love and approval, being a primary source of comfort, and possibly seeking more love. However, it introduces additional interpretations not present in the reference, like seeking a man's attention.
#
# - **Faithfulness (7):** While the model accurately reflects some parts of the context, it also includes elements that are speculative or not directly supported by the reference answer, such as the child potentially wanting a man's attention and lack of structure in life.
#
# - **Answer Relevance (9):** The response is largely relevant to the question about why the child seeks the mother's attention. It addresses multiple reasons but slightly deviates with additional interpretations.
# Parsing error: ```json
# {
#   "answer_correctness": 4,
#   "faithfulness": 3,
#   "answer_relevance": 5
# }
# ```
#
# Explanation:
# - **Answer Correctness (4):** The model's answer does not provide specific transportation options, which is a significant omission. It only vaguely implies that a car might be an option without any concrete details.
#
# - **Faithfulness (3):** The model's response does not accurately reflect the context provided. The context explicitly states there is no information on transportation options, yet the model attempts to infer possibilities.
#
# - **Answer Relevance (5):** While the answer addresses the question about transportation options, it fails to provide any useful or specific information, making it only partially relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer captures two of the three main objectives mentioned in the reference answer but omits the third objective, which is to increase the interest of young people for employment in regional investment sectors.
# - **Faithfulness (9):** The model accurately reflects the information provided in the context regarding the seminar's objectives. However, it misses one part of the full objective list.
# - **Answer Relevance (10):** The answer directly addresses the question about the main objective of the seminar and is relevant to the query posed.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most features and benefits accurately. However, it omits specific details such as product dimensions and maximum user weight.
# - **Faithfulness (9):** The response aligns well with the provided context but lacks some specifics like exact measurements and weight capacity.
# - **Answer Relevance (10):** The model's answer directly addresses the question about features and benefits, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 5,
#   "answer_relevance": 9
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer partially matches the reference by mentioning "functional furniture components," but it omits "cutting off work pieces."
# - **Faithfulness (5):** The context provided multiple uses for wood lathes, including cutting threads and making tools. The model's response does not fully capture this breadth.
# - **Answer Relevance (9):** The answer is relevant to the question about what wood lathes can be used for but lacks completeness.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most components accurately. However, it includes a "Vocabulary Notebook" as an activity recommended for active reading, which is not explicitly listed in the reference answer but mentioned in the context.
#
# - **Faithfulness (9):** The model's response aligns well with the provided context and captures the essential elements of the British Medieval Student Guide. It accurately reflects the components described in the context.
#
# - **Answer Relevance (10):** The model directly addresses the question about the components of the guide, making it highly relevant to the query.
# ```
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is mostly correct but omits some details from the reference answer, such as the exclusion of events sponsored by other organizations like PTA or booster groups.
# - **Faithfulness (9):** The model accurately reflects the context provided in the text. However, it misses a small detail about the limitations on event types covered by the Gold Card.
# - **Answer Relevance (10):** The answer directly addresses who is eligible for the Gold Card and what benefits it provides, making it highly relevant to the question asked.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference, capturing all key features mentioned. However, it slightly rephrases some parts and omits mentioning customizable formatting options.
# - **Faithfulness (9):** The model accurately reflects the context provided in the text, including specific details about adding various elements like images, videos, links, etc.
# - **Answer Relevance (10):** The answer directly addresses the question by listing features of Spark Page used for creating a website.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer correctly identifies the series as "Planet Earth Live" and provides accurate details about its broadcast. However, it slightly lacks the explicit mention of tracking animals in seven different locations around the world in real time, which is a key detail from the reference answer.
#
# - **Faithfulness (9):** The model's response aligns well with the provided context, accurately reflecting the broadcasting channels and exclusions mentioned. It does not introduce any incorrect information but omits some minor details about the series' scope.
#
# - **Answer Relevance (10):** The model directly addresses the question by naming the series and explaining how it is being broadcasted, making the response highly relevant to the query.
# ```
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference answer, with additional context about the location ("at Annie Kaill's") which is accurate but not explicitly required by the question.
# - **Faithfulness (9):** The model accurately reflects the provided context and includes relevant details without introducing errors or irrelevant information.
# - **Answer Relevance (10):** The response directly addresses the question, providing a clear and concise answer about the event taking place on that specific date.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for Scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer but includes additional details about accelerating economic recovery and adaptation, increasing public safety, furthering economic policies, and capitalizing on “next-normal” opportunities. These additions are accurate according to the context but go beyond the specific elements mentioned in the reference answer.
# - **Faithfulness (9):** The model's response is faithful to the provided context, accurately reflecting the purpose of the website as described. However, it includes additional details not explicitly required by the question or reference answer.
# - **Answer Relevance (10):** The model’s answer directly addresses the question about the purpose of the new website, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation for Scores:**
#
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, covering all key points such as dietary changes, omega-3 fatty acids, other supplements, nattokinase, and flavonoid-rich extracts. It slightly deviates by not explicitly mentioning "monounsaturated fats" from the reference but includes similar relevant information.
#
# - **Faithfulness (9):** The model's answer is faithful to the context provided, accurately reflecting the content about natural ways to prevent excessive platelet aggregation and reduce heart disease risk. It maintains the integrity of the original text with minor omissions that do not significantly alter the meaning.
#
# - **Answer Relevance (10):** The response directly addresses the question by listing specific natural methods to prevent excessive platelet aggregation, making it highly relevant to the query.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all key methods mentioned. However, it slightly rephrases some parts and omits mentioning that social media interactions might not always indicate cheating, which is a nuance present in the context.
# - **Faithfulness (9):** The model accurately reflects the content of the provided text, maintaining the intent and details without introducing inaccuracies or misleading information. It does not include all nuances about social media but remains faithful to the main points.
# - **Answer Relevance (10):** The answer directly addresses the question by listing specific methods for determining if a partner is cheating, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer but omits some details such as having experience in eCommerce platforms and CMS systems.
# - **Faithfulness (9):** The response is faithful to the context provided, accurately reflecting most of the roles and responsibilities mentioned.
# - **Answer Relevance (10):** The answer directly addresses the question about the roles and responsibilities of the Front-End Developer position.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer includes most of the features mentioned in the reference answer but omits some details such as the folding capability, speed limit, and turning radius. Additionally, it incorrectly states that there is a "comfortable seat" without mentioning the absence of armrests.
#
# - **Faithfulness (9):** The model's response aligns well with the provided context, accurately reflecting most features mentioned in the text.
#
# - **Answer Relevance (9):** The answer directly addresses the question about the features of the KD Wise Seat electric wheelchair but misses a few key points from the reference answer.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all key points accurately. It includes understanding client needs, contract details, honesty in communication, and being selective with clients. A minor deduction is made because it does not explicitly mention "communicate effectively" as a separate point, though it is implied.
# - **Faithfulness (10):** The model's answer faithfully represents the information provided in the context without adding or omitting significant details.
# - **Answer Relevance (10):** The response directly addresses the question about best practices to avoid unnecessary revisions and conflicts.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer captures the dismissive aspect of the public reaction but omits other significant reactions such as criticism for being self-serving and disappointment from conservatives. This results in a partial match with the reference answer.
#
# - **Faithfulness (7):** While the model accurately reflects part of the context regarding voters dismissing claims, it fails to include criticisms and expressions of disappointment mentioned in the text.
#
# - **Answer Relevance (9):** The model's response is relevant as it addresses the public reaction to Noem's press release. However, it does not fully encompass all aspects of the reaction described in the reference answer.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference answer, capturing all key features accurately. However, it lists them in a bullet-point format rather than a continuous paragraph as in the reference.
# - **Faithfulness (10):** The model's response aligns perfectly with the provided context and includes all relevant details without adding or omitting any information.
# - **Answer Relevance (10):** The answer directly addresses the question about the features of the snow thrower, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is mostly correct but lacks some specific details from the reference answer, such as mentioning that Russian Helicopters Holding Company is a subsidiary of Oboronprom Corporation and part of Russian Technologies State Corporation.
# - **Faithfulness (9):** The model accurately reflects the context provided in terms of operational capabilities. However, it omits the detail about the helicopter being manufactured by Ulan-Ude Aviation Plant.
# - **Answer Relevance (10):** The answer directly addresses who delivered the Mi-171E and its operational capabilities, making it highly relevant to the question asked.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is very close to the reference, capturing most of the services accurately. However, it slightly rephrases some parts and omits mentioning "distribution of press releases" explicitly.
# - **Faithfulness (9):** The response aligns well with the context provided, covering all major service categories mentioned in the company profile.
# - **Answer Relevance (10):** The model's answer directly addresses the question about services offered by Kartz Media & PR.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is very close to the reference, capturing the main purpose of using ECC in bridge joint repair. It mentions replacing conventional joints and retrofitting bridges with ECC link slabs, which aligns well with the reference. However, it slightly lacks the specific mention of "removing the expansion joint" as stated in the reference.
# - **Faithfulness (9):** The model's answer is faithful to the context provided, accurately reflecting Victor Li’s work and its objectives. It correctly identifies the problem of deteriorating mechanical expansion joints and the solution proposed by using ECC link slabs.
# - **Answer Relevance (10):** The model's response directly addresses the question about the purpose of using ECC in bridge joint repair according to Victor Li's work, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, accurately detailing the steps involved in obtaining jail records. However, it includes additional context about potential delays if the offender does not have their records at release, which is not explicitly mentioned in the reference.
#
# - **Faithfulness (9):** The model faithfully represents the information provided in the context, including details about contacting the Registry and possible fees. It maintains accuracy with respect to the original text.
#
# - **Answer Relevance (10):** The answer directly addresses the question regarding the process of obtaining jail records in Cheshire County, New Hampshire, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, listing all nine best practices accurately. However, it slightly rephrases some points which could be seen as minor deviations.
# - **Faithfulness (9):** The model's response is faithful to the context provided, capturing the essence of each practice without introducing inaccuracies or omissions.
# - **Answer Relevance (10):** The answer directly addresses the question about best practices for achieving marketing success on YouTube, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 7,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, accurately summarizing each candidate's reaction. However, it includes an additional interpretation about candidates recognizing their inability to "right the American ship of state," which is not part of the direct reactions.
#
# - **Faithfulness (7):** While the core information aligns with the context, the inclusion of a statement regarding the candidates' recognition of their limitations introduces an element that goes beyond the specific question about reactions.
#
# - **Answer Relevance (10):** The model's answer directly addresses the question by providing a breakdown of each candidate's reaction to the liberation in Oregon.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer by accurately describing the concept of 'criminal-consumer' and its origins. It includes relevant details about Gary Becker’s application of neo-classical price theory to crime, which aligns well with the reference. A point is deducted for not explicitly mentioning Foucault's description in the same way as the reference.
#
# - **Faithfulness (9):** The model faithfully represents the context by accurately capturing the essence of 'criminal-consumer' and its theoretical background. It maintains fidelity to the original text, though it could have included more direct quotes or references from the context for a perfect score.
#
# - **Answer Relevance (10):** The answer directly addresses the question about the concept of 'criminal-consumer,' making it highly relevant and focused on the query posed.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference answer, with all ingredients correctly listed. However, it includes additional details such as measurements and notes about oil depth that are not present in the reference answer.
# - **Faithfulness (10):** The model accurately reflects the information provided in the context without any distortion or omission of key elements.
# - **Answer Relevance (10):** The response directly addresses the question by listing all necessary ingredients for making Lángos.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost perfectly aligned with the reference answer, providing both individual and combined portrait sizes accurately. However, it includes additional information about the approximate image size and white border which was not in the reference but does not detract from correctness.
# - **Faithfulness (10):** The model's response faithfully represents the context provided, including all relevant details without any inaccuracies or omissions.
# - **Answer Relevance (10):** The answer directly addresses the question about available sizes for individual and combined portraits, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation for Scores:**
#
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most of the key features mentioned. However, it omits the detail about operating on the latest version of Android and supporting 3G wireless connections while not supporting 4G data connections.
#
# - **Faithfulness (10):** The model accurately reflects the information provided in the context without introducing any inaccuracies or extraneous details.
#
# - **Answer Relevance (10):** The answer directly addresses the question about key features of the Cat B15 smartphone, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference answer, capturing all essential details about how the wort chiller works. However, it omits a minor detail from the reference answer: "The water then flows back through the plastic tube and dumps into the sink."
#
# - **Faithfulness (9):** The model’s response accurately reflects the context provided in the passage. It correctly describes the components and function of the wort chiller as detailed in the original text.
#
# - **Answer Relevance (10):** The answer directly addresses the question about what device Craig used to cool down the wort quickly and how it works, making it highly relevant.
# ```
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer correctly identifies two shortcomings but omits others mentioned in the reference, such as outdated color choices and functionality. It also incorrectly implies that only two shortcomings are listed when more are referenced.
# - **Faithfulness (9):** The response is mostly faithful to the context provided, accurately reflecting the points about out-of-date design and lack of responsive design.
# - **Answer Relevance (10):** The answer directly addresses the question regarding common shortcomings in underperforming practice websites.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 10,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost perfectly aligned with the reference answer, capturing both Opam and Typeshed as prerequisites. However, it includes additional details about using a specific command (`$ opam switch 4.06.0`) which, while accurate, was not explicitly required by the reference.
# - **Faithfulness (10):** The model's response is entirely faithful to the context provided in the text, accurately reflecting the prerequisites mentioned for building Pyre from source.
# - **Answer Relevance (10):** The answer directly addresses the question about prerequisites for building Pyre from source without any irrelevant information.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is highly accurate and closely matches the reference answer. It correctly describes what the Gumblar attack is and provides detailed steps to fix it, aligning well with the reference.
#
# - **Faithfulness (9):** The model faithfully represents the context provided, accurately conveying the nature of the Gumblar attack and the recommended remediation steps without introducing errors or omissions.
#
# - **Answer Relevance (10):** The answer directly addresses the question about what the Gumblar attack is and how it can be fixed, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer is highly accurate and aligns closely with the reference answer. It correctly identifies that individuals assisting in suicide without personal gain will not be prosecuted, mentions the geographical scope of the guidelines, and clarifies that these are changes to guidelines rather than law. A minor deduction is made because it does not explicitly mention that legalizing assisted suicide remains a matter for parliament.
#
# - **Faithfulness (9):** The model's answer faithfully represents the context provided. It accurately captures the essence of the new guidelines and their implications without introducing any inaccuracies or misinterpretations.
#
# - **Answer Relevance (10):** The response directly addresses the question about changes to the assisted suicide law's guidelines in Britain and Wales in 2009, making it highly relevant.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer accurately captures the structure and essence of the argument against physicalism as described in the context. It correctly identifies P1, P2, and C, and explains why the author finds this form of argument flawed due to a misinterpretation of P1. A point is deducted because it does not explicitly mention that the author believes acceptance of phenomena F should not depend on the truth of physicalism.
# - **Faithfulness (9):** The model's answer aligns well with the context, accurately reflecting the author's critique and reasoning regarding the argument against physicalism. It maintains fidelity to the original text by explaining the misinterpretation issue without adding extraneous information. A point is deducted for not explicitly mentioning the author's stance on the independence of phenomena F from metaphysical claims.
# - **Answer Relevance (10):** The model's answer directly addresses the question about the argument against physicalism, providing a clear and relevant explanation that matches the context provided.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model's answer captures part of the reason for disbandment ("years of disappointment and still no recording contract"), but it omits key details from the reference answer, such as the offer to change their name and the fact that they sold off their instruments.
# - **Faithfulness (9):** The model's response is mostly faithful to the context provided. It accurately reflects part of the narrative about the band's struggles with record companies but misses some specific elements mentioned in the reference answer.
# - **Answer Relevance (10):** The model's answer directly addresses the question regarding what led to the disbandment, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (7):** The model correctly identifies Bubble Sort, Insertion Sort, Shell Sort, and Comb Sort as easy to implement. However, it omits Quick Sort and Merge Sort, which are mentioned in the context as efficient.
# - **Faithfulness (7):** The answer aligns with the provided context but misses mentioning Quick Sort and Merge Sort as efficient methods, leading to a slight deviation from the full context.
# - **Answer Relevance (9):** The model's response directly addresses the question about sorting methods mentioned as efficient and easy to implement, though it lacks completeness by not including all relevant methods.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation for Scores:
# - **Answer Correctness (7):** The model's answer correctly identifies the performing arts and entrepreneurship programs but omits details about the Big Breakfast event, inviting community leaders, and presenting skits or talent shows.
# - **Faithfulness (7):** While the model accurately describes the performing arts and entrepreneurship components, it misses other activities mentioned in the context such as the Big Breakfast event and interactions with community leaders.
# - **Answer Relevance (9):** The answer is relevant to the question about summer program activities but lacks completeness by not mentioning all included activities.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing the essence of "fine-grained urbanism" as proposed by Andrew Price. It accurately describes selling larger lots to multiple smaller developers and mentions the benefits such as diverse property ownership, lower cost of entry, varied places to visit, and less bad architecture. However, it slightly lacks the explicit mention of signaling that the city wants more people involved in development, which is present in the reference answer.
#
# - **Faithfulness (9):** The model's response aligns well with the context provided, accurately reflecting Andrew Price's concept and its implications for Long Beach's urban development. It maintains fidelity to the original text without introducing inaccuracies or misinterpretations.
#
# - **Answer Relevance (10):** The answer directly addresses the question about "fine-grained urbanism" in the context of Long Beach's development, providing a clear and relevant explanation that aligns with the query.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost identical to the reference, but it omits mentioning that the card needs to be signed at the back during phone activation.
# - **Faithfulness (9):** The model accurately reflects the context provided, with only a minor omission regarding signing the card.
# - **Answer Relevance (10):** The response directly addresses how to activate the WeSwap card and obtain a new PIN.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer captures the essence of Project Angel Heart’s mission but lacks specific details such as meal creation, delivery, and nutritional education and counseling. It mentions “food is medicine” which aligns with the reference.
# - **Faithfulness (9):** The model accurately reflects the context by emphasizing access to nutrition and the concept of "food is medicine," though it omits some program specifics.
# - **Answer Relevance (10):** The answer directly addresses the question about Project Angel Heart’s mission, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer includes all key players mentioned in the reference answer and adds Ehab Amin and Payton Pritchard, who are relevant but not explicitly listed as key players. This slight deviation from the reference answer results in a score of 9.
# - **Faithfulness (9):** The model accurately reflects the context by listing the key players and providing additional relevant information about senior and junior contributors. However, it includes more detail than necessary for identifying "key" players, leading to a score of 9.
# - **Answer Relevance (10):** The answer directly addresses the question by listing the key players in the Oregon Ducks men’s basketball 2018-2019 season, making it highly relevant.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# ...
# - **Answer Relevance (10):** The answer directly addresses the question by summarizing the reviews, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 5,
#   "faithfulness": 7,
#   "answer_relevance": 4
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (5):** The model's answer partially captures the context by mentioning the richness and diversity of buckwheats but fails to address their ornamental significance or ecological role, which are key points in the reference answer.
# - **Faithfulness (7):** The model accurately reflects part of the provided context regarding the presence of buckwheats throughout the garden. However, it omits significant details about their importance during summer months.
# - **Answer Relevance (4):** While the model's response is related to the topic, it does not directly address the question about the significance of buckwheats in the garden during summer months, missing key aspects such as their ornamental and ecological roles.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer captures the essence of why the route is significant, mentioning it as a "stupendously inspired choice" and highlighting its scenic nature. However, it lacks specific details from the reference answer such as the start at the World Heritage salt factory and the pride associated with Arc-et-Senars.
# - **Faithfulness (7):** The model's response is generally faithful to the context but omits some key elements like the time trial aspect and the national pride in hosting a stage in Arc-et-Senars. It also doesn't mention the marking of the route with yellow bicycles and "9éme étape."
# - **Answer Relevance (9):** The model's answer is relevant to the question, addressing why the route is significant by focusing on its scenic and inspired nature. However, it could be more comprehensive in covering all aspects mentioned in the reference answer.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing most of the key features. However, it omits mentioning that the pump is ideal for applications where a Walbro 255 fuel pump won't suffice and does not specify the flow rate at 13.5v.
# - **Faithfulness (9):** The model accurately reflects the context provided in the description, including details about efficiency, compatibility, and included components. It slightly deviates by not mentioning specific vehicle applications or minor cradle modifications.
# - **Answer Relevance (10):** The answer directly addresses the question regarding features of the Walbro 460 lph fuel pump, making it highly relevant to the query.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all key factors mentioned. However, it slightly rephrases and organizes them differently than the reference.
# - **Faithfulness (9):** The model accurately reflects the context provided in the text, including details about company match offers, financial situations, mindset towards money, age considerations, and company restrictions.
# - **Answer Relevance (10):** The answer directly addresses the question by listing relevant factors for deciding 401k contributions.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, covering all key points. However, it omits the mention of scheduled meetings with HR during the first 30, 60, and 90 days.
# - **Faithfulness (9):** The response accurately reflects the context provided, capturing most elements mentioned in the checklist.
# - **Answer Relevance (10):** The answer directly addresses the question about what should be explained to new managers during their onboarding process.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# **Explanation:**
#
# - **Answer Correctness (9):** The model's answer is highly accurate and aligns closely with the reference answer. It correctly outlines the credit system, costs, and payment details. A minor deduction is made because it does not explicitly mention that women can start chats without financial commitment, though this is implied.
#
# - **Faithfulness (9):** The model faithfully represents the information from the context provided. All key points about the pricing structure, cost per action, and payment methods are accurately conveyed. The slight omission of explicit mention regarding women's free chat initiation leads to a small deduction.
#
# - **Answer Relevance (10):** The answer directly addresses the question about the cost and workings of Ashley Madison's credit system, making it highly relevant. It covers all necessary aspects without deviation from the core inquiry.
# Parsing error: ```json
# {
#   "answer_correctness": 7,
#   "faithfulness": 7,
#   "answer_relevance": 9
# }
# ```
#
# Explanation:
# - **Answer Correctness (7):** The model's answer partially matches the reference by mentioning the difference in Bekah's hand placement, but it does not explicitly state that this was a technique used to create depth. It focuses more on the outcome rather than the method.
# - **Faithfulness (7):** The model accurately reflects the context regarding how Bekah’s smaller size contributed to the appearance of depth, but it doesn't fully capture the essence of "creating depth with bleach resist" as a deliberate technique.
# - **Answer Relevance (9):** The answer is relevant and addresses the question about creating depth in the artwork, though it could be more precise in linking this directly to the technique used.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing all essential steps. However, it slightly rephrases some parts and omits minor details like mentioning that you need to have a list of shelfmarks when turning up with ID.
#
# - **Faithfulness (9):** The model accurately reflects the context provided, maintaining the sequence and key elements of the procedure. It does not introduce any incorrect information but slightly condenses certain steps.
#
# - **Answer Relevance (10):** The answer directly addresses the question about accessing the British Library's collection, providing a clear and relevant step-by-step guide.
# ```
#
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer is almost entirely correct, capturing all key changes mentioned in the reference answer. However, it adds an extra point about combined data research that was not explicitly required by the question.
# - **Faithfulness (9):** The model accurately reflects the context provided, with no significant deviations or inaccuracies.
# - **Answer Relevance (10):** The response directly addresses the question regarding changes implemented in January 2003.
# Parsing error: ```json
# {
#   "answer_correctness": 9,
#   "faithfulness": 9,
#   "answer_relevance": 10
# }
# ```
#
# Explanation for the scores:
# - **Answer Correctness (9):** The model's answer closely matches the reference answer, capturing key points such as reduced staff turnover, improved sales performance, increased profitability, and enhanced motivation. However, it slightly deviates by not explicitly mentioning "performance" in the context of consultants meeting or exceeding budgets.
#
# - **Faithfulness (9):** The model accurately reflects the content provided in the context, including details about leadership involvement and team accountability.
#
# - **Answer Relevance (10):** The answer directly addresses how personal goal setting impacted employee engagement and performance, making it highly relevant to the question.
#                                                context  \
# 0    Caption: Tasmanian berry grower Nic Hansen sho...
# 1    RWSN Collaborations\nSouthern Africa Self-supp...
# 2    All Android applications categories\nDescripti...
# 3    How unequal is India? The question is simple, ...
# 4    Gunnar Nelson took his time on the feet agains...
# ..                                                 ...
# 995  Last Sunday, as part of a brunch with friends,...
# 996  Printable View\nhow often does Orlando Hire?\n...
# 997  A recent survey of Canadian workers by pension...
# 998  As soon as it hits October I start planning my...
# 999  At some point a couple of weeks ago my blog tu...
#
#                                               question  \
# 0    What is the Berry Export Summary 2028 and what...
# 1    What are some of the benefits reported from ha...
# 2    What are the unique features of the Coolands f...
# 3    What is the main difference between the Nation...
# 4    How did Gunnar Nelson win the fight against Za...
# ..                                                 ...
# 995  What was the unanimous favourite chocolate bar...
# 996  What does the SAFER grant require Orlando to d...
# 997  What percentage of Canadian workers with a tra...
# 998  What type of pears are recommended for making ...
# 999  Why did the author decide to leave Blogger for...
#
#                                                 answer  \
# 0    The Berry Export Summary 2028 is a dedicated e...
# 1    Benefits reported from having access to Self-s...
# 2    The unique features of the Coolands for Twitte...
# 3    The main difference between the NSS and the IH...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  The unanimous favourite was the Organic Cappuc...
# 996  The SAFER grant requires Orlando to replace an...
# 997  50 per cent of workers with a traditional defi...
# 998  Anjou pears, Bosc pears, and Bartlett pears ar...
# 999  The author decided to leave Blogger because it...
#
#                                          answerllama8b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the text, the benefits reported f...
# 2    According to the text, the unique features of ...
# 3    According to the text, the main difference bet...
# 4    According to the text, Gunnar Nelson won the f...
# ..                                                 ...
# 995  According to the text, the unanimous favourite...
# 996  According to the text, the SAFER grant require...
# 997  According to the survey, 50% of workers with a...
# 998  According to the text, the following types of ...
# 999  According to the text, the author decided to l...
#
#                                          answerllama3b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the provided text, the benefits r...
# 2    According to the provided text, the unique fea...
# 3    According to the text, the main difference bet...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  According to the text, the Organic Cappuccino ...
# 996  According to the text, under the SAFER grant, ...
# 997  According to the text, 50% of Canadian workers...
# 998  According to the text, two types of pears are ...
# 999  According to the text, the author left Blogger...
#
#                                       answerGemma3:12b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the text, benefits reported from ...
# 2    According to the provided text, here are the u...
# 3    According to the provided text, the main diffe...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  According to the text, the unanimous favorite ...
# 996  According to the text, the SAFER grant require...
# 997  According to the text, 50 per cent of workers ...
# 998  The text recommends Anjou pears as the ideal c...
# 999  According to the text, the author left Blogger...
#
#      answer_correctness_llama3b  faithfulness_llama3b  \
# 0                             9                     9
# 1                             9                    10
# 2                             9                     9
# 3                             9                     9
# 4                             9                     9
# ..                          ...                   ...
# 995                           9                     9
# 996                           9                     9
# 997                          10                    10
# 998                           9                    10
# 999                           9                     9
#
#      answer_relevance_llama3b  answer_correctness_llama8b  \
# 0                          10                          -1
# 1                          10                           9
# 2                          10                           9
# 3                          10                           9
# 4                          10                           9
# ..                        ...                         ...
# 995                        10                           9
# 996                        10                           9
# 997                        10                          10
# 998                        10                           9
# 999                        10                           9
#
#      faithfulness_llama8b  answer_relevance_llama8b  \
# 0                      -1                        -1
# 1                      10                        10
# 2                       9                        10
# 3                       9                        10
# 4                      10                        10
# ..                    ...                       ...
# 995                     9                        10
# 996                     9                        10
# 997                    10                        10
# 998                    10                        10
# 999                     9                        10
#
#      answer_correctness_answerGemma3:12b  faithfulness_answerGemma3:12b  \
# 0                                      9                             10
# 1                                     10                             10
# 2                                      9                              9
# 3                                      9                             10
# 4                                      9                              9
# ..                                   ...                            ...
# 995                                   10                             10
# 996                                   10                             10
# 997                                   10                             10
# 998                                    9                              9
# 999                                    9                             10
#
#      answer_relevance_answerGemma3:12b
# 0                                   10
# 1                                   10
# 2                                   10
# 3                                   10
# 4                                   10
# ..                                 ...
# 995                                 10
# 996                                 10
# 997                                 10
# 998                                 10
# 999                                 10
#
# [1000 rows x 15 columns]

# %%
df_result=df_final.copy()

# %%
df_result
# Out:
#                                                context  \
# 0    Caption: Tasmanian berry grower Nic Hansen sho...
# 1    RWSN Collaborations\nSouthern Africa Self-supp...
# 2    All Android applications categories\nDescripti...
# 3    How unequal is India? The question is simple, ...
# 4    Gunnar Nelson took his time on the feet agains...
# ..                                                 ...
# 995  Last Sunday, as part of a brunch with friends,...
# 996  Printable View\nhow often does Orlando Hire?\n...
# 997  A recent survey of Canadian workers by pension...
# 998  As soon as it hits October I start planning my...
# 999  At some point a couple of weeks ago my blog tu...
#
#                                               question  \
# 0    What is the Berry Export Summary 2028 and what...
# 1    What are some of the benefits reported from ha...
# 2    What are the unique features of the Coolands f...
# 3    What is the main difference between the Nation...
# 4    How did Gunnar Nelson win the fight against Za...
# ..                                                 ...
# 995  What was the unanimous favourite chocolate bar...
# 996  What does the SAFER grant require Orlando to d...
# 997  What percentage of Canadian workers with a tra...
# 998  What type of pears are recommended for making ...
# 999  Why did the author decide to leave Blogger for...
#
#                                                 answer  \
# 0    The Berry Export Summary 2028 is a dedicated e...
# 1    Benefits reported from having access to Self-s...
# 2    The unique features of the Coolands for Twitte...
# 3    The main difference between the NSS and the IH...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  The unanimous favourite was the Organic Cappuc...
# 996  The SAFER grant requires Orlando to replace an...
# 997  50 per cent of workers with a traditional defi...
# 998  Anjou pears, Bosc pears, and Bartlett pears ar...
# 999  The author decided to leave Blogger because it...
#
#                                          answerllama8b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the text, the benefits reported f...
# 2    According to the text, the unique features of ...
# 3    According to the text, the main difference bet...
# 4    According to the text, Gunnar Nelson won the f...
# ..                                                 ...
# 995  According to the text, the unanimous favourite...
# 996  According to the text, the SAFER grant require...
# 997  According to the survey, 50% of workers with a...
# 998  According to the text, the following types of ...
# 999  According to the text, the author decided to l...
#
#                                          answerllama3b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the provided text, the benefits r...
# 2    According to the provided text, the unique fea...
# 3    According to the text, the main difference bet...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  According to the text, the Organic Cappuccino ...
# 996  According to the text, under the SAFER grant, ...
# 997  According to the text, 50% of Canadian workers...
# 998  According to the text, two types of pears are ...
# 999  According to the text, the author left Blogger...
#
#                                       answerGemma3:12b  \
# 0    According to the text, the Berry Export Summar...
# 1    According to the text, benefits reported from ...
# 2    According to the provided text, here are the u...
# 3    According to the provided text, the main diffe...
# 4    Gunnar Nelson won the fight against Zak Cummin...
# ..                                                 ...
# 995  According to the text, the unanimous favorite ...
# 996  According to the text, the SAFER grant require...
# 997  According to the text, 50 per cent of workers ...
# 998  The text recommends Anjou pears as the ideal c...
# 999  According to the text, the author left Blogger...
#
#      answer_correctness_llama3b  faithfulness_llama3b  \
# 0                             9                     9
# 1                             9                    10
# 2                             9                     9
# 3                             9                     9
# 4                             9                     9
# ..                          ...                   ...
# 995                           9                     9
# 996                           9                     9
# 997                          10                    10
# 998                           9                    10
# 999                           9                     9
#
#      answer_relevance_llama3b  answer_correctness_llama8b  \
# 0                          10                          -1
# 1                          10                           9
# 2                          10                           9
# 3                          10                           9
# 4                          10                           9
# ..                        ...                         ...
# 995                        10                           9
# 996                        10                           9
# 997                        10                          10
# 998                        10                           9
# 999                        10                           9
#
#      faithfulness_llama8b  answer_relevance_llama8b  \
# 0                      -1                        -1
# 1                      10                        10
# 2                       9                        10
# 3                       9                        10
# 4                      10                        10
# ..                    ...                       ...
# 995                     9                        10
# 996                     9                        10
# 997                    10                        10
# 998                    10                        10
# 999                     9                        10
#
#      answer_correctness_answerGemma3:12b  faithfulness_answerGemma3:12b  \
# 0                                      9                             10
# 1                                     10                             10
# 2                                      9                              9
# 3                                      9                             10
# 4                                      9                              9
# ..                                   ...                            ...
# 995                                   10                             10
# 996                                   10                             10
# 997                                   10                             10
# 998                                    9                              9
# 999                                    9                             10
#
#      answer_relevance_answerGemma3:12b
# 0                                   10
# 1                                   10
# 2                                   10
# 3                                   10
# 4                                   10
# ..                                 ...
# 995                                 10
# 996                                 10
# 997                                 10
# 998                                 10
# 999                                 10
#
# [1000 rows x 15 columns]

# %%
df_result=df_result[df_result['answer_correctness_llama3b']!=-1]

# %%
df_result=df_result[df_result['answer_correctness_llama8b']!=-1]

# %%
df_result=df_result[df_result['answerGemma3:12b']!=-1]

# %%
df_result = df_result.reset_index(drop=True)

# %%
df_result
# Out:
#                                                context  \
# 0    RWSN Collaborations\nSouthern Africa Self-supp...
# 1    All Android applications categories\nDescripti...
# 2    How unequal is India? The question is simple, ...
# 3    Gunnar Nelson took his time on the feet agains...
# 4    The prices indicated in this catalogue do not ...
# ..                                                 ...
# 806  Last Sunday, as part of a brunch with friends,...
# 807  Printable View\nhow often does Orlando Hire?\n...
# 808  A recent survey of Canadian workers by pension...
# 809  As soon as it hits October I start planning my...
# 810  At some point a couple of weeks ago my blog tu...
#
#                                               question  \
# 0    What are some of the benefits reported from ha...
# 1    What are the unique features of the Coolands f...
# 2    What is the main difference between the Nation...
# 3    How did Gunnar Nelson win the fight against Za...
# 4    What are some of the features of Fabiana Filip...
# ..                                                 ...
# 806  What was the unanimous favourite chocolate bar...
# 807  What does the SAFER grant require Orlando to d...
# 808  What percentage of Canadian workers with a tra...
# 809  What type of pears are recommended for making ...
# 810  Why did the author decide to leave Blogger for...
#
#                                                 answer  \
# 0    Benefits reported from having access to Self-s...
# 1    The unique features of the Coolands for Twitte...
# 2    The main difference between the NSS and the IH...
# 3    Gunnar Nelson won the fight against Zak Cummin...
# 4    Fabiana Filippi's shirts and blouses are easil...
# ..                                                 ...
# 806  The unanimous favourite was the Organic Cappuc...
# 807  The SAFER grant requires Orlando to replace an...
# 808  50 per cent of workers with a traditional defi...
# 809  Anjou pears, Bosc pears, and Bartlett pears ar...
# 810  The author decided to leave Blogger because it...
#
#                                          answerllama8b  \
# 0    According to the text, the benefits reported f...
# 1    According to the text, the unique features of ...
# 2    According to the text, the main difference bet...
# 3    According to the text, Gunnar Nelson won the f...
# 4    According to the text, some of the key feature...
# ..                                                 ...
# 806  According to the text, the unanimous favourite...
# 807  According to the text, the SAFER grant require...
# 808  According to the survey, 50% of workers with a...
# 809  According to the text, the following types of ...
# 810  According to the text, the author decided to l...
#
#                                          answerllama3b  \
# 0    According to the provided text, the benefits r...
# 1    According to the provided text, the unique fea...
# 2    According to the text, the main difference bet...
# 3    Gunnar Nelson won the fight against Zak Cummin...
# 4    According to the text, some features of Fabian...
# ..                                                 ...
# 806  According to the text, the Organic Cappuccino ...
# 807  According to the text, under the SAFER grant, ...
# 808  According to the text, 50% of Canadian workers...
# 809  According to the text, two types of pears are ...
# 810  According to the text, the author left Blogger...
#
#                                       answerGemma3:12b  \
# 0    According to the text, benefits reported from ...
# 1    According to the provided text, here are the u...
# 2    According to the provided text, the main diffe...
# 3    Gunnar Nelson won the fight against Zak Cummin...
# 4    According to the text, here are some features ...
# ..                                                 ...
# 806  According to the text, the unanimous favorite ...
# 807  According to the text, the SAFER grant require...
# 808  According to the text, 50 per cent of workers ...
# 809  The text recommends Anjou pears as the ideal c...
# 810  According to the text, the author left Blogger...
#
#      answer_correctness_llama3b  faithfulness_llama3b  \
# 0                             9                    10
# 1                             9                     9
# 2                             9                     9
# 3                             9                     9
# 4                             9                    10
# ..                          ...                   ...
# 806                           9                     9
# 807                           9                     9
# 808                          10                    10
# 809                           9                    10
# 810                           9                     9
#
#      answer_relevance_llama3b  answer_correctness_llama8b  \
# 0                          10                           9
# 1                          10                           9
# 2                          10                           9
# 3                          10                           9
# 4                          10                           9
# ..                        ...                         ...
# 806                        10                           9
# 807                        10                           9
# 808                        10                          10
# 809                        10                           9
# 810                        10                           9
#
#      faithfulness_llama8b  answer_relevance_llama8b  \
# 0                      10                        10
# 1                       9                        10
# 2                       9                        10
# 3                      10                        10
# 4                      10                        10
# ..                    ...                       ...
# 806                     9                        10
# 807                     9                        10
# 808                    10                        10
# 809                    10                        10
# 810                     9                        10
#
#      answer_correctness_answerGemma3:12b  faithfulness_answerGemma3:12b  \
# 0                                     10                             10
# 1                                      9                              9
# 2                                      9                             10
# 3                                      9                              9
# 4                                     -1                             -1
# ..                                   ...                            ...
# 806                                   10                             10
# 807                                   10                             10
# 808                                   10                             10
# 809                                    9                              9
# 810                                    9                             10
#
#      answer_relevance_answerGemma3:12b
# 0                                   10
# 1                                   10
# 2                                   10
# 3                                   10
# 4                                   -1
# ..                                 ...
# 806                                 10
# 807                                 10
# 808                                 10
# 809                                 10
# 810                                 10
#
# [811 rows x 15 columns]

# %%
df_result.to_csv('df_rag_result.csv',index=False)
